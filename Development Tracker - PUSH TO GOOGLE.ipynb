# %%
## Establish connection to Account
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://dougsack:Ocana2421@cluster1.zdl0b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['InDevelopment']

collection = db['development_tracker']

# %%
docs = collection.find({})

# %%
import pandas as pd

df = pd.DataFrame(docs)

# %%
df
# Out:
#                                                _id  ITD_current_year  \
# 0                                 Five Hitmen_Film         344775.01
# 1                    Twelve Minutes (Anim/TV)_Film         107786.66
# 2           Untitled Lessovitz, Quesada, Zund_Film          80040.06
# 3                 The Silent Patient - Plan B_Film        2003145.55
# 4                           Unt James Sweeney_Film         190318.63
# ..                                             ...               ...
# 87                 Conner (Literary Research)_Film         225950.00
# 88                          Stephen Feder fee_Film         603798.56
# 89  This Immaculate Body (fka Heartstring)_Intl_TV           3584.29
# 90                        A Lie for a Life_Intl_TV              0.00
# 91                        This Perfect Day_Intl_TV              0.00
#
#     Remaining_Committed  Remaining_Optional  Total_Cost_with_Committments  \
# 0             74550.000           102506.25                    521831.260
# 1            320625.000                 NaN                    428411.660
# 2                 0.000                 NaN                     80040.060
# 3             31062.500            15531.25                   2049739.300
# 4            331933.875            48457.50                    570710.005
# ..                  ...                 ...                           ...
# 87            31900.000                 NaN                    257850.000
# 88            71162.000                 NaN                    674960.560
# 89            87125.000                 NaN                     90709.290
# 90                  NaN                 NaN                         0.000
# 91                0.000                 NaN                         0.000
#
#    division               status                                   title  \
# 0      film  closed deals/active                             Five Hitmen
# 1      film  closed deals/active                Twelve Minutes (Anim/TV)
# 2      film  closed deals/active       Untitled Lessovitz, Quesada, Zund
# 3      film  closed deals/active             The Silent Patient - Plan B
# 4      film  closed deals/active                       Unt James Sweeney
# ..      ...                  ...                                     ...
# 87     film  closed deals/active              Conner (Literary Research)
# 88     film  closed deals/active                       Stephen Feder fee
# 89  intl_tv              pending  This Immaculate Body (fka Heartstring)
# 90  intl_tv              pending                        A Lie for a Life
# 91  intl_tv              pending                        This Perfect Day
#
#                update_date                                            updates
# 0  2026-02-23 10:52:16.567  [{'update_date': 2026-02-17 14:57:00.405000, '...
# 1  2026-02-23 10:52:16.567  [{'update_date': 2026-02-17 14:57:00.405000, '...
# 2  2026-02-23 10:52:16.567  [{'update_date': 2026-02-17 14:57:00.405000, '...
# 3  2026-02-23 10:52:16.567  [{'update_date': 2026-02-17 14:57:00.405000, '...
# 4  2026-02-23 10:52:16.567  [{'update_date': 2026-02-17 14:57:00.405000, '...
# ..                     ...                                                ...
# 87 2026-02-23 10:52:16.567  [{'update_date': 2026-02-17 14:57:00.405000, '...
# 88 2026-02-23 10:52:16.567  [{'update_date': 2026-02-17 14:57:00.405000, '...
# 89 2026-02-23 10:52:16.567  [{'update_date': 2026-02-23 10:33:43.615000, '...
# 90 2026-02-23 10:52:16.567  [{'update_date': 2026-02-23 10:33:43.615000, '...
# 91 2026-02-23 10:52:16.567  [{'update_date': 2026-02-23 10:33:43.615000, '...
#
# [92 rows x 10 columns]

# %%
client.close()

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
data = df[['_id', 'Remaining_Committed','Total_Cost_with_Committments', 'ITD_current_year']]

# %%
data = data.fillna("")

# %%
data = data.set_index("_id")
data = data.reset_index()

# %%
data_export = [data.columns.tolist()] + data.values.tolist()

# %%
data_export
# Out:
# [['_id',
#   'Remaining_Committed',
#   'Total_Cost_with_Committments',
#   'ITD_current_year'],
#  ['Five Hitmen_Film', 74550.0, 521831.26, 344775.01],
#  ['Twelve Minutes (Anim/TV)_Film', 320625.0, 428411.66, 107786.65999999999],
#  ['Untitled Lessovitz, Quesada, Zund_Film', 0.0, 80040.06, 80040.06],
#  ['The Silent Patient - Plan B_Film', 31062.5, 2049739.3, 2003145.55],
#  ['Unt James Sweeney_Film', 331933.875, 570710.005, 190318.63],
#  ['Untitled Dolly Parton_Film', 436625.0, 441925.0, 5300.0],
#  ['Finding Gobi_Film', 372750.0, 406342.5, 33592.5],
#  ['Norco 80_Film', 0.0, 202306.26, 202306.26],
#  ['Even the Losers/ Unt. Randy Lanier_Film', 1763125.0, 4607503.5, 2094378.5],
#  ['Cuban Missile Crisis_Film', 226025.0, 553950.0, 187925.0],
#  ['Syd_Film', 0.0, 260925.0, 260925.0],
#  ['American Jewel_Film', 101272.32, 134265.80000000002, 32993.48],
#  ['Chef_Film', 63332.95524999999, 67637.95525, 4305.0],
#  ['The Lost Wild - Film_Film', '', 1100.0, 1100.0],
#  ['Unt Nicole Taylor_Film', 439968.75, 782926.25, 282957.5],
#  ['American Spartan_Film', 623750.0, 623750.0, 0.0],
#  ['Unt Bennett Miller (fka Untitled Charlie Kaufman Project)_Film',
#   454687.5,
#   543851.15,
#   89163.65000000002],
#  ['Eric Warren Singer_Film', 4500000.0, 4500000.0, 0.0],
#  ['Grind_Film', 471975.0, 696525.0, 224550.0],
#  ['Blankets_Film', 210000.0, 210000.0, ''],
#  ['The Legend of Georgia McBride_Film', 249500.0, 249500.0, 0.0],
#  ['Belly of the Beast_Film', 64233.380000000005, 194338.24, 55104.86],
#  ['The Visit_Film', 52000.0, 52268.17, 268.17],
#  ['Women Clothed by the Sun_Film', '', 30638.73, 30638.73],
#  ['Unt Soap Opera Doc_Film', '', 3135.0, 3135.0],
#  ['Unt Brady Corbett Project_Film', '', 1205.0, 1205.0],
#  ['Monument Valley_Film', '', 0.0, 0.0],
#  ['Minds on Fire_Film', '', 0.0, 0.0],
#  ['Control_TV', 763465.0, 763465.0, 0.0],
#  ['Who is Maud Dixon_TV', 0.0, 664105.11, 559938.11],
#  ['Planet of Exile_TV', 13894.0, 400129.41000000003, 386235.41000000003],
#  ['Murderland_TV', 475000.0, 475000.0, 0.0],
#  ['Hot Kid_TV', 9062.5, 411947.82, 402885.32],
#  ['The Original_TV', 0.0, 415398.73000000004, 415398.73000000004],
#  ['Call Me Dad_TV', 50000.0, 363842.39, 313842.39],
#  ['The Voyeur_TV', 217437.5, 217437.5, 0.0],
#  ['Unt. Carlo Bernard/International Mercenaries_TV', 0.0, 154062.5, 154062.5],
#  ['Operator_TV', 22146.894249999998, 134178.31425, 112031.42],
#  ['The Tour_TV', 0.0, 128031.0, 128031.0],
#  ['The Chosen One_TV', 0.0, 111769.27000000002, 111769.27000000002],
#  ['Identical_TV', 25000.0, 60000.0, 35000.0],
#  ['Seized_TV', 0.0, 50000.0, 50000.0],
#  ['Made in Utah_TV', 10000.0, 40467.5, 30467.5],
#  ['Untitled Mallory Project_TV',
#   -274506.10000000003,
#   32478.22999999998,
#   306984.33],
#  ['Strangers_TV', 0.0, 30000.0, 30000.0],
#  ['Darkside of the Moon_TV', 8550.0, 29883.33, 21333.33],
#  ['Unt. Death Hoax_TV', 0.0, 1141.21, 1141.21],
#  ['Alan Wake_TV', 150000.0, 150000.0, 0.0],
#  ['Unt. Shi Yang_TV', 0.0, 0.0, 0.0],
#  ['The Drifting Classroom_TV', 40000.0, 40000.0, 0.0],
#  ['Shot to Nothing_TV', 621250.0, 621250.0, 0.0],
#  ['Unt. Equestrian Series_TV', 0.0, 0.0, 0.0],
#  ['Nomad Summer_TV', 25001.2475, 75001.2475, 50000.0],
#  ['Unt. Game Doc Series_TV', 0.0, 4208.32, 4208.32],
#  ['Unt. John Cho Jean Kyoung Frazier (if/come)_TV', '', 450.0, 450.0],
#  ['Executive Protection_TV', '', 0.0, 0.0],
#  ['Unt. Sports Fan Show_TV', 30000.0, 30000.0, 0.0],
#  ['Inside_TV', '', 0.0, 0.0],
#  ['Limbo (TV/FILM tbd)_TV', '', 0.0, 0.0],
#  ['Cutter & Tats_TV', '', 0.0, 0.0],
#  ['Heartstring_Intl_TV', 87125.0, 90709.29, 3584.29],
#  ['Calliope_corporate', 33900.0, 78324.64, 44424.64],
#  ['Some Assembly Required_Animation_Film',
#   298056.0,
#   655473.4299999999,
#   357417.43],
#  ['Killingbeck_Intl_TV', 4450.0, 4450.0, 0.0],
#  ['Stray - Animation_Animation_Film',
#   1595209.0,
#   2698611.37,
#   1103402.3699999999],
#  ['England Expects (Film)_corporate', '', 46154.0, 46154.0],
#  ['Mantooth_Animation_Film', 120000.0, 2568846.95, 2448846.95],
#  ['Grant & Sherman_corporate', 0.0, 10000.0, 10000.0],
#  ['Moomins_Animation_Film', 479220.0, 1115549.58, 636329.5800000001],
#  ['Nimona_Animation_Film', 0.0, 5802.780000000006, 5802.780000000006],
#  ['COMA_Animation_Film', 414500.0, 514555.08999999997, 100055.09],
#  ['FOO (Animation)_Animation_Film',
#   0.0,
#   266996.26000000024,
#   266996.26000000024],
#  ['To be billed back_Animation_Film',
#   0.0,
#   146285.06999999998,
#   146285.06999999998],
#  ['Sapiens - Animation_Animation_TV',
#   1425.0,
#   95869.79000000001,
#   107544.79000000001],
#  ['Antarctica_Animation_Film', 0.0, 86000.0, 86000.0],
#  ['The Trap_Animation_Film', 0.0, 13421.619999999999, 13421.619999999999],
#  ["Let's Boogey_Animation_Film", 0.0, 1568.98, 1568.98],
#  ['Nick Weidenfeld_Animation_TV', 541375.0, 1066512.3199999998, 626593.07],
#  ['Living the Dream_Animation_TV', 80177.0, 80177.0, 0.0],
#  ['20,000 Leagues Under the Sea_Animation_TV', 51142.0, 51142.0, 0.0],
#  ['NARPS (Non-Associated Regular People)_Animation_TV', 43485.0, 43485.0, 0.0],
#  ['Witchfeld_Animation_TV', 0.0, 0.0, 0.0],
#  ['Outlets_Animation_TV', 0.0, 0.0, 0.0],
#  ['Center Stage_Theatre', 170000.0, 340000.0, 0.0],
#  ['Her_Theatre', 50000.0, 100000.0, 0.0],
#  ['Inter Alia (Broadway 2026)_Theatre', '', 0.0, 0.0],
#  ['Conner (Literary Research)_TV', 31900.0, 260750.0, 228850.0],
#  ['Conner (Literary Research)_Film', 31900.0, 257850.0, 225950.0],
#  ['Stephen Feder fee_Film', 71162.0, 674960.56, 603798.56],
#  ['This Immaculate Body (fka Heartstring)_Intl_TV',
#   87125.0,
#   90709.29,
#   3584.29],
#  ['A Lie for a Life_Intl_TV', '', 0.0, 0.0],
#  ['This Perfect Day_Intl_TV', 0.0, 0.0, 0.0]]

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Step 1: Define the scope
scope = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive",
]

# Step 2: Load credentials
creds = ServiceAccountCredentials.from_json_keyfile_name("ultra-sound-463216-c2-0e076e5f88fe.json", scope)

# Step 3: Authorize and connect
client = gspread.authorize(creds)

# Step 4: Open sheet by URL
sheet_url = "https://docs.google.com/spreadsheets/d/1PaAQEAJcTupLNgvTLaawyWPKOfIrUFAQf-WiUnZMbxY/edit?gid=25505532#gid=25505532"
spreadsheet = client.open_by_url(sheet_url)

# Optional: Access specific sheet/tab
sheet = spreadsheet.worksheet("dev_tracker_data")  # or spreadsheet.worksheet("SheetName")

# %%
# Example: Read data
sheet.clear()
# Out:
# {'spreadsheetId': '1PaAQEAJcTupLNgvTLaawyWPKOfIrUFAQf-WiUnZMbxY',
#  'clearedRange': 'dev_tracker_data!A1:Z1000'}

# %%
sheet.update(data_export)
# Out:
# {'spreadsheetId': '1PaAQEAJcTupLNgvTLaawyWPKOfIrUFAQf-WiUnZMbxY',
#  'updatedRange': 'dev_tracker_data!A1:D93',
#  'updatedRows': 93,
#  'updatedColumns': 4,
#  'updatedCells': 372}
