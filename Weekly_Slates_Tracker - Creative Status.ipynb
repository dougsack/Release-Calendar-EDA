# %%
import warnings

warnings.filterwarnings("ignore")

# %%
from googleapiclient.discovery import build
from google.oauth2 import service_account

SCOPES = ['https://www.googleapis.com/auth/drive.readonly']
FILE_ID = '160xlgPZeHcDNDL0htvlyS-EYot9B9CuNiQSu2VJlV5I'

creds = service_account.Credentials.from_service_account_file(
    'ultra-sound-463216-c2-0e076e5f88fe.json', scopes=SCOPES
)

service = build('drive', 'v3', credentials=creds)

# Export to text
exported = service.files().export(fileId=FILE_ID, mimeType='text/plain').execute()
text = exported.decode('utf-8')
print(text)
# Out:
# ﻿NEW - TV Slate
# Pat, any ME related action items to add?
#
#
# ————
#
#
# ME Related Action Items
# * ME & PC to discuss next steps on BADLANDS
# * ME hearing MAUD DIXON practice pitch 10/20
# * ME to join any virtual MAUD or TOUR pitches if avail - PAT?
#
#
#
#
# SET UP AT NETWORKS
#
# THE CHOSEN ONE
# * W/EP: Rachel Wenitsky
# * T/EP: Maya Hawke
# * NWEP: Michael Showalter & Jordana Mollick (Semi-Formal)
# * NWEP: Zoe Worth
# * Logline: THE CHOSEN ONE is a comedy/fantasy hybrid about a 20-something who discovers a magical realm (think Narnia) inside a shitty old IKEA dresser that she brings in off the street.
#
# MATERIALS: Currently rebreaking the Outline with Amazon. Series pitch before selling to Amazon. *also pevious pilot draft from Peacock development
#
# ...

# %%
category_breaks = [
    
    'SET UP AT NETWORKS',
    'PITCHING 2025',
    'POTENTIALLY PITCHING 2025',
    'INTERNAL DEVELOPMENT',
    'TV ANIMATION',
    'PENDING DEALS',
    'IN POST // AWAITING RELEASE',
    'ADVANCED DEVELOPMENT',
    'EXISTING SLATE',
    'PENDING DEALS',
    'EXTERNAL DEVELOPMENT'

]
