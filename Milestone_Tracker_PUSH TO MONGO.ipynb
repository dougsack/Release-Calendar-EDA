# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Step 1: Define the scope
scope = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive",
]

# Step 2: Load credentials
creds = ServiceAccountCredentials.from_json_keyfile_name("ultra-sound-463216-c2-0e076e5f88fe.json", scope)

# Step 3: Authorize and connect
client = gspread.authorize(creds)

# Step 4: Open sheet by URL
sheet_url = "https://docs.google.com/spreadsheets/d/1JVNtgSJFswHEH6iHz-XP1qUzdyxQXa5Q-WGI86CqGmE/edit?gid=1534679013#gid=1534679013"
spreadsheet = client.open_by_url(sheet_url)

# Optional: Access specific sheet/tab
sheet = spreadsheet.worksheet("Data")  # or spreadsheet.worksheet("SheetName")

# Example: Read data
data = sheet.get_all_records(head=1)

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
df.columns
# Out:
# Index(['hub_id', 'Title', 'writing_start', 'writing_end', 'prep_start',
#        'Prep_end', 'shoot_start', 'shoot_end', 'post_start', 'post_end',
#        'delivery', 'est_release_date'],
#       dtype='object')

# %% [raw]
# df["Title"] = df["Project"].str.title()

# %%
date_cols = ['writing_start', 'writing_end', 'prep_start',
       'Prep_end', 'shoot_start', 'shoot_end', 'post_start', 'post_end',
       'delivery', 'est_release_date']

# %%
df[date_cols] = df[date_cols].apply(pd.to_datetime, errors="coerce")

df = df.replace({pd.NaT: None})

# %%
df
# Out:
#        hub_id                                     Title        writing_start  \
# 0                                       I Love Boosters                 None
# 1   828769775                                The Invite                 None
# 2                                                 Soaps                 None
# 3                                    Belly of the Beast  2026-01-01 00:00:00
# 4                                             25 Scenes  2026-01-01 00:00:00
# 5              Unt. Brady Corbet (est. budget: net 20M)  2026-01-01 00:00:00
# 6                     Norco 80 (bud target: net 40-50M)  2026-01-01 00:00:00
# 7   857713278    American Jewel (bud target: net 8-15M)  2026-01-01 00:00:00
# 8                  Silent Patient (bud target: net 25M)  2026-01-01 00:00:00
# 9   857711298     Even The Losers (bud target: net 80M)  2026-01-01 00:00:00
# 10                           Chef (bud target: net 20M)  2026-01-01 00:00:00
# ...

# %%
df.columns = (
    df.columns
      .str.lower()
      .str.strip()
      .str.replace(r"\s+", "_", regex=True)   # spaces -> underscore
      .str.replace(r"[^0-9a-zA-Z_]", "", regex=True)  # optional: remove weird chars
      + "_film_milestone_tracker"
)

# %%
df
# Out:
#    hub_id_film_milestone_tracker              title_film_milestone_tracker  \
# 0                                                          I Love Boosters
# 1                      828769775                                The Invite
# 2                                                                    Soaps
# 3                                                       Belly of the Beast
# 4                                                                25 Scenes
# 5                                 Unt. Brady Corbet (est. budget: net 20M)
# 6                                        Norco 80 (bud target: net 40-50M)
# 7                      857713278    American Jewel (bud target: net 8-15M)
# 8                                     Silent Patient (bud target: net 25M)
# 9                      857711298     Even The Losers (bud target: net 80M)
# 10                                              Chef (bud target: net 20M)
# ...

# %%
mongo_cols = ['_id', 'title_film_milestone_tracker',
       'writing_start_film_milestone_tracker',
       'writing_end_film_milestone_tracker',
       'prep_start_film_milestone_tracker', 'prep_end_film_milestone_tracker',
       'shoot_start_film_milestone_tracker',
       'shoot_end_film_milestone_tracker', 'post_start_film_milestone_tracker',
       'post_end_film_milestone_tracker', 'delivery_film_milestone_tracker',
       'est_release_date_film_milestone_tracker']

# %%
df["_id"] = df['hub_id_film_milestone_tracker']
df=df[mongo_cols]

# %%
df.head().columns
# Out:
# Index(['_id', 'title_film_milestone_tracker',
#        'writing_start_film_milestone_tracker',
#        'writing_end_film_milestone_tracker',
#        'prep_start_film_milestone_tracker', 'prep_end_film_milestone_tracker',
#        'shoot_start_film_milestone_tracker',
#        'shoot_end_film_milestone_tracker', 'post_start_film_milestone_tracker',
#        'post_end_film_milestone_tracker', 'delivery_film_milestone_tracker',
#        'est_release_date_film_milestone_tracker'],
#       dtype='object')

# %%
df
# Out:
#           _id              title_film_milestone_tracker  \
# 0                                       I Love Boosters
# 1   828769775                                The Invite
# 2                                                 Soaps
# 3                                    Belly of the Beast
# 4                                             25 Scenes
# 5              Unt. Brady Corbet (est. budget: net 20M)
# 6                     Norco 80 (bud target: net 40-50M)
# 7   857713278    American Jewel (bud target: net 8-15M)
# 8                  Silent Patient (bud target: net 25M)
# 9   857711298     Even The Losers (bud target: net 80M)
# 10                           Chef (bud target: net 20M)
# 11                 Five Hitmen (bud target: net 30-40M)
# 12                    Unt. James Sweeney (bud target: )
# 13                    Unt. Nicole Taylor (bud target: )
#
#    writing_start_film_milestone_tracker writing_end_film_milestone_tracker  \
# ...

# %%
df = df[df["_id"] != ""]
#df['_id'] = df['_id'].astype('str')

# %%
df
# Out:
#          _id            title_film_milestone_tracker  \
# 1  828769775                              The Invite
# 7  857713278  American Jewel (bud target: net 8-15M)
# 9  857711298   Even The Losers (bud target: net 80M)
#
#   writing_start_film_milestone_tracker writing_end_film_milestone_tracker  \
# 1                                 None                               None
# 7                  2026-01-01 00:00:00                2026-09-01 00:00:00
# 9                  2026-01-01 00:00:00                2026-08-15 00:00:00
#
#   prep_start_film_milestone_tracker prep_end_film_milestone_tracker  \
# 1                              None                            None
# 7               2026-09-01 00:00:00             2026-11-01 00:00:00
# 9               2026-08-15 00:00:00             2026-11-01 00:00:00
#
#   shoot_start_film_milestone_tracker shoot_end_film_milestone_tracker  \
# 1                               None                             None
# ...

# %%
data = df.to_dict(orient='records')

# %%
data
# Out:
# [{'_id': 828769775,
#   'title_film_milestone_tracker': 'The Invite',
#   'writing_start_film_milestone_tracker': None,
#   'writing_end_film_milestone_tracker': None,
#   'prep_start_film_milestone_tracker': None,
#   'prep_end_film_milestone_tracker': None,
#   'shoot_start_film_milestone_tracker': None,
#   'shoot_end_film_milestone_tracker': None,
#   'post_start_film_milestone_tracker': None,
#   'post_end_film_milestone_tracker': None,
#   'delivery_film_milestone_tracker': None,
#   'est_release_date_film_milestone_tracker': Timestamp('2026-06-26 00:00:00')},
#  {'_id': 857713278,
#   'title_film_milestone_tracker': 'American Jewel (bud target: net 8-15M)',
#   'writing_start_film_milestone_tracker': Timestamp('2026-01-01 00:00:00'),
#   'writing_end_film_milestone_tracker': Timestamp('2026-09-01 00:00:00'),
#   'prep_start_film_milestone_tracker': Timestamp('2026-09-01 00:00:00'),
#   'prep_end_film_milestone_tracker': Timestamp('2026-11-01 00:00:00'),
# ...

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
## Establish connection to Account
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://dougsack:Ocana2421@cluster1.zdl0b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['InDevelopment']

collection = db['milestone_tracker']

# %%
def batchify(data, batch_size):
    for i in range(0, len(data), batch_size):
        yield data[i:i + batch_size]

# %% [raw]
# collection.delete_many({})

# %%
from pymongo import UpdateOne


#####
for batch in batchify(data, 4000):
    operations = [
        UpdateOne(
            {"hub_id": doc["_id"]},
            {"$set": doc},
            upsert=True
        ) for doc in batch
    ]
    
    result = collection.bulk_write(operations)
    print(f"Matched: {result.matched_count}, Inserted: {result.upserted_count}, Modified: {result.modified_count}")
# Out:
# Matched: 0, Inserted: 3, Modified: 0

# %%
from datetime import datetime


datetime.today()
# Out:
# datetime.datetime(2026, 3, 4, 10, 48, 2, 354042)

# %% [raw]
# client.close()

# %%
db = client['InDevelopment']
collection = db['milestone_tracker']
query = {"hub_id": 857713278}

mt_query_docs = collection.find(query)
df = pd.DataFrame(mt_query_docs)

df
# Out:
#          _id     hub_id delivery_film_milestone_tracker  \
# 0  857713278  857713278                      2027-07-01
#
#   est_release_date_film_milestone_tracker post_end_film_milestone_tracker  \
# 0                                    None                      2027-07-01
#
#   post_start_film_milestone_tracker prep_end_film_milestone_tracker  \
# 0                        2027-01-01                      2026-11-01
#
#   prep_start_film_milestone_tracker shoot_end_film_milestone_tracker  \
# 0                        2026-09-01                       2027-01-01
#
#   shoot_start_film_milestone_tracker            title_film_milestone_tracker  \
# 0                         2026-11-01  American Jewel (bud target: net 8-15M)
#
#   writing_end_film_milestone_tracker writing_start_film_milestone_tracker
# 0                         2026-09-01                           2026-01-01

# %%
df.T
# Out:
#                                                                               0
# _id                                                                   857713278
# hub_id                                                                857713278
# delivery_film_milestone_tracker                             2027-07-01 00:00:00
# est_release_date_film_milestone_tracker                                    None
# post_end_film_milestone_tracker                             2027-07-01 00:00:00
# post_start_film_milestone_tracker                           2027-01-01 00:00:00
# prep_end_film_milestone_tracker                             2026-11-01 00:00:00
# prep_start_film_milestone_tracker                           2026-09-01 00:00:00
# shoot_end_film_milestone_tracker                            2027-01-01 00:00:00
# shoot_start_film_milestone_tracker                          2026-11-01 00:00:00
# title_film_milestone_tracker             American Jewel (bud target: net 8-15M)
# ...
