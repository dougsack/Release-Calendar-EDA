# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Step 1: Define the scope
scope = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive",
]

# Step 2: Load credentials
creds = ServiceAccountCredentials.from_json_keyfile_name("ultra-sound-463216-c2-0e076e5f88fe.json", scope)

# Step 3: Authorize and connect
client = gspread.authorize(creds)

# Step 4: Open sheet by URL
sheet_url = "https://docs.google.com/spreadsheets/d/1CVrRk4--uOQx5iEtAUd798LeJM8g_jxA3qr634guj18/edit?gid=748703564#gid=748703564"
spreadsheet = client.open_by_url(sheet_url)

# Optional: Access specific sheet/tab
sheet = spreadsheet.worksheet("Animation")  # or spreadsheet.worksheet("SheetName")

# Example: Read data
data = sheet.get_all_records(head=1)

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
animation_titles = [
    'ANTARCTICA',
'FOO',
'MOOMINS',
'SAPIENS',
'SOME ASSEMBLY REQUIRED',
'STRAY (Film) ',
'THE BROBARIANS (FKA MANTOOTH)',
'TRAP, THE ',
'VALE, THE  (FKA COMA)' ,
'20,000 LEAGUES UNDER THE SEA',
'LIVING THE DREAM',
'NARPS',
'OUTLETS',
'WITCHFELD',
'NIMONA (Film)',
'OUTER WILDS (TV)',
'SAUSAGE PARTY (TV)',
'SAUSAGE PARTY (Film)'
                   ]

# %%
df = df.query("Title ==@animation_titles")

# %%
df['division_flag'] = 'Animation'

# %%
df["Title"] = df["Title"].str.title()

# %%
df
# Out:
#                              Title                   AP DIVISION  \
# 2                       Antarctica               Animation, Film
# 10                             Foo               Animation, Film
# 51                         Moomins               Animation, Film
# 76                         Sapiens    Animation, TV, Interactive
# 83          Some Assembly Required               Animation, Film
# 87                   Stray (Film)   Animation, Interactive, Film
# 92   The Brobarians (Fka Mantooth)               Animation, Film
# 99                      Trap, The                Animation, Film
# 110   20,000 Leagues Under The Sea                 Animation, TV
# 111               Living The Dream                 Animation, TV
# 112                          Narps                 Animation, TV
# 122                        Outlets                 Animation, TV
# 128                      Witchfeld                 Animation, TV
# ...

# %%
df.columns = (
    df.columns
      .str.lower()
      .str.strip()
      .str.replace(r"\s+", "_", regex=True)   # spaces -> underscore
      .str.replace(r"[^0-9a-zA-Z_]", "", regex=True)  # optional: remove weird chars
      + "_film_pt"
)

# %%
df = df.rename({"title_film_pt":"_id"}, axis=1)

# %%
cols = [
    '_id', 
        'ap_division_film_pt', 
        'project_stage_film_pt',
       'ap_lead_film_pt', 
        'ap_jr_film_pt', 
        'ap_dev_film_pt',
       'ba_status_film_pt', 
        'creative_status_film_pt',
       'next_milestone_film_pt', 
        'key_timing_film_pt',
       'option_expiration_film_pt', 
        'key_timing_date_film_pt',
       'underlying_ip_film_pt', 
        'logline_film_pt',
       'platform__distribution_film_pt', 
        'deal_type_film_pt',
       'partners_and_vendors_film_pt', 
        'creators_film_pt', 
        'director_film_pt',
       'writers_film_pt', 
        'producer_1_film_pt', 
        'producer_2_film_pt',
       'cast_1_film_pt', 
        'cast_2_film_pt', 
        'cast_3_film_pt', 
        'cast_4_film_pt',
    'division_flag_film_pt'
       ]

# %%
#df["project_stage_film_pt"] = df["project_stage_film_pt"].str.split(",").apply(lambda x: [i.strip() for i in x])
df["ap_lead_film_pt"] = df["ap_lead_film_pt"].str.split(",").apply(lambda x: [i.strip() for i in x])
df["ap_jr_film_pt"] = df["ap_jr_film_pt"].str.split(",").apply(lambda x: [i.strip() for i in x])
df["ap_division_film_pt"] = df["ap_division_film_pt"].str.split(",").apply(lambda x: [i.strip() for i in x])

# %%
df[cols]
# Out:
#                                _id             ap_division_film_pt  \
# 2                       Antarctica               [Animation, Film]
# 10                             Foo               [Animation, Film]
# 51                         Moomins               [Animation, Film]
# 76                         Sapiens    [Animation, TV, Interactive]
# 83          Some Assembly Required               [Animation, Film]
# 87                   Stray (Film)   [Animation, Interactive, Film]
# 92   The Brobarians (Fka Mantooth)               [Animation, Film]
# 99                      Trap, The                [Animation, Film]
# 110   20,000 Leagues Under The Sea                 [Animation, TV]
# 111               Living The Dream                 [Animation, TV]
# 112                          Narps                 [Animation, TV]
# 122                        Outlets                 [Animation, TV]
# 128                      Witchfeld                 [Animation, TV]
# ...

# %%
title_map = {
    "Even The Losers (Fka Need For Weed)": "Even the Losers",
    "Belly Of The Beast": "Belly of The Beast",
    'Brady Corbet / Mona Fastvold Project (Unt.)': "Origin of the World fka Unt. Brady Corbet & Mona Fastvold Project",

    'Silent Patient, The ': "The Silent Patient",
    '12 Minutes (Film)': "12 Minutes",
    'Bennett Miller (Unt.) ':"Unt. Bennett Miller",
    
    'Nicole Taylor Idea (Unt.)':"Evie Mcbrayne fka Unt. Nicole Taylor",
    'James Sweeney (Unt.)':"Unt. James Sweeney",
    'Into The Glory Whole':"Into the Glory whole",
    'Legend Of Georgia Mcbride, The ':"The Legend of Georgia McBride",

        'Lost Wild, The ':"The Lost Wild",


        'Beast Fiction Project (Unt.)':"Unt. Beast Fiction Project",

            'Ann Lee (Fka The Woman Clothed By The Sun) ':"The Testament of Ann Lee",



    # add more…
}

df['_id'] = df['_id'].replace(title_map)

# %%
df.query("_id=='The Invite'")
# Out:
# Empty DataFrame
# Columns: [_id, ap_division_film_pt, project_stage_film_pt, ap_lead_film_pt, ap_jr_film_pt, ap_dev_film_pt, ba_status_film_pt, creative_status_film_pt, next_milestone_film_pt, option_expiration_film_pt, key_timing_film_pt, key_timing_date_film_pt, underlying_ip_film_pt, logline_film_pt, platform__distribution_film_pt, deal_type_film_pt, partners_and_vendors_film_pt, creators_film_pt, director_film_pt, writers_film_pt, producer_1_film_pt, producer_2_film_pt, cast_1_film_pt, cast_2_film_pt, cast_3_film_pt, cast_4_film_pt, ba_update_time_film_pt, creative_status_update_time_film_pt, key_timing_update_time_film_pt, slack_channel_id_film_pt, links_film_pt, division_flag_film_pt]
# Index: []
#
# [0 rows x 32 columns]

# %%
df.head().columns
# Out:
# Index(['_id', 'ap_division_film_pt', 'project_stage_film_pt',
#        'ap_lead_film_pt', 'ap_jr_film_pt', 'ap_dev_film_pt',
#        'ba_status_film_pt', 'creative_status_film_pt',
#        'next_milestone_film_pt', 'option_expiration_film_pt',
#        'key_timing_film_pt', 'key_timing_date_film_pt',
#        'underlying_ip_film_pt', 'logline_film_pt',
#        'platform__distribution_film_pt', 'deal_type_film_pt',
#        'partners_and_vendors_film_pt', 'creators_film_pt', 'director_film_pt',
#        'writers_film_pt', 'producer_1_film_pt', 'producer_2_film_pt',
#        'cast_1_film_pt', 'cast_2_film_pt', 'cast_3_film_pt', 'cast_4_film_pt',
#        'ba_update_time_film_pt', 'creative_status_update_time_film_pt',
#        'key_timing_update_time_film_pt', 'slack_channel_id_film_pt',
#        'links_film_pt', 'division_flag_film_pt'],
#       dtype='object')

# %%
data = df.to_dict(orient='records')

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
## Establish connection to Account
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://dougsack:Ocana2421@cluster1.zdl0b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['InDevelopment']

collection = db['projects']

# %%
def batchify(data, batch_size):
    for i in range(0, len(data), batch_size):
        yield data[i:i + batch_size]

# %% [raw]
# collection.delete_many({})

# %%
from pymongo import UpdateOne


#####
for batch in batchify(data, 4000):
    operations = [
        UpdateOne(
            {"_id": doc["_id"]},
            {"$set": doc},
            upsert=True
        ) for doc in batch
    ]
    
    result = collection.bulk_write(operations)
    print(f"Matched: {result.matched_count}, Inserted: {result.upserted_count}, Modified: {result.modified_count}")
# Out:
# Matched: 17, Inserted: 0, Modified: 1

# %%
from datetime import datetime


datetime.today()
# Out:
# datetime.datetime(2025, 12, 16, 10, 41, 17, 162791)

# %%
client.close()
