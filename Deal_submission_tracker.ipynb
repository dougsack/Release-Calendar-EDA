# %%
### Grab Updated Sheet

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Step 1: Define the scope
scope = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive",
]

# Step 2: Load credentials
creds = ServiceAccountCredentials.from_json_keyfile_name("ultra-sound-463216-c2-0e076e5f88fe.json", scope)

# Step 3: Authorize and connect
client = gspread.authorize(creds)

# Step 4: Open sheet by URL
sheet_url = "https://docs.google.com/spreadsheets/d/1ESVir3YAXUiX2tgxPMxfxB5MmFzp0IMWQDQvLJsbKJg/edit?resourcekey=&gid=710601441#gid=710601441"
spreadsheet = client.open_by_url(sheet_url)

# Optional: Access specific sheet/tab
sheet = spreadsheet.worksheet("deal_submissions")  # or spreadsheet.worksheet("SheetName")

# Example: Read data
data = sheet.get_all_records()

# %%
### Process Data

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
df.head()
# Out:
#                                            deal_id   Timestamp  \
# 0     2025114_Finding Gobi_Writer_Samuel D. Hunter   11/4/2025
# 1  2025116_The Silent Patient_Writer_Claire Wilson   11/6/2025
# 2         20251116_Voyeur_Producing_Rege-Jean Page  11/16/2025
# 3        2025111_RUSSIAN FIVE_Writer_Dave Holstein   11/1/2025
#
#         Project Title  Deal Type  \
# 0        Finding Gobi     Writer
# 1  The Silent Patient     Writer
# 2              Voyeur  Producing
# 3        RUSSIAN FIVE     Writer
#
#                                     Deal Description    Talent / Party  \
# 0  Guaranteed Steps: WGA Scale + 10% for a treatm...  Samuel D. Hunter
# 1  Two guaranteed writing weeks at $25,000 each w...     Claire Wilson
# 2  Talent Deal for Rege-Jean Page to star in VOYE...    Rege-Jean Page
# 3  Script Deal for Dave Holstein to write a film ...     Dave Holstein
#
#                                       talent context  \
# 0    Sam is an acclaimed playwright as well as a ...
# ...

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df['closed_date'] = pd.to_datetime(df['closed_date'])
df['commencement date'] = pd.to_datetime(df['commencement date'])
df['BA Updated'] = pd.to_datetime(df['BA Updated'])

# %%
df
# Out:
#                                            deal_id  Timestamp  \
# 0     2025114_Finding Gobi_Writer_Samuel D. Hunter 2025-11-04
# 1  2025116_The Silent Patient_Writer_Claire Wilson 2025-11-06
# 2         20251116_Voyeur_Producing_Rege-Jean Page 2025-11-16
# 3        2025111_RUSSIAN FIVE_Writer_Dave Holstein 2025-11-01
#
#         Project Title  Deal Type  \
# 0        Finding Gobi     Writer
# 1  The Silent Patient     Writer
# 2              Voyeur  Producing
# 3        RUSSIAN FIVE     Writer
#
#                                     Deal Description    Talent / Party  \
# 0  Guaranteed Steps: WGA Scale + 10% for a treatm...  Samuel D. Hunter
# 1  Two guaranteed writing weeks at $25,000 each w...     Claire Wilson
# 2  Talent Deal for Rege-Jean Page to star in VOYE...    Rege-Jean Page
# 3  Script Deal for Dave Holstein to write a film ...     Dave Holstein
#
#                                       talent context  \
# 0    Sam is an acclaimed playwright as well as a ...
# ...

# %%
from datetime import datetime

doc_list = []

for _, row in df.iterrows():

    doc = {
        '_id': row['deal_id'],
        'title': row['Project Title'],
        'division': row['Intended Format'],
        'Type': row['Deal Type'],
        'deal_description': row['Deal Description'],
        'Parties': row['Talent / Party'],
        'talent_context': row['talent context'],
        'represenation': row['Representation'],
        'requester': row['Email Address'],
        'ingoing_offer': row['Ingoing Offer'],
        'negotiating_ceiling': row['negotiating ceiling'],
        'project_details': row['Format/ Length/ Log-line / Based on real people/events?'],
        'requester': row['Email Address'],
        'requested_date': row['Timestamp'],
        'BA_POC': row['BA POC'],
        'BA_deal_status': row['BA_deal_status'],
        'status': row['status'],

#        'BA Updated': row['BA Updated'],
     #   'closed_date': row['closed_date'],
    #    'commencement_date': row['commencement date'],
        
    }

    doc_list.append(doc)

# %%
from datetime import datetime

doc_list_commence = []

for _, row in df.dropna(subset='commencement date').iterrows():

    doc = {
        '_id': row['deal_id'],
        'commencement_date': row['commencement date'],
        
    }

    doc_list_commence.append(doc)

# %%
from datetime import datetime

doc_list_closed = []

for _, row in df.dropna(subset='closed_date').iterrows():

    doc = {
        '_id': row['deal_id'],
        'closed_date': row['closed_date'],
        
    }

    doc_list_closed.append(doc)

# %%
from datetime import datetime

doc_list_updated = []

for _, row in df.dropna(subset='BA Updated').iterrows():

    doc = {
        '_id': row['deal_id'],
        'BA Updated': row['BA Updated'],
        
    }

    doc_list_updated.append(doc)

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
## Establish connection to Account
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://dougsack:Ocana2421@cluster1.zdl0b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['InDevelopment']

collection = db['deal_submissions']

# %% [raw]
# collection.delete_many({})

# %%
def batchify(data, batch_size):
    for i in range(0, len(data), batch_size):
        yield data[i:i + batch_size]

# %%
from pymongo import UpdateOne


#####
for batch in batchify(doc_list, 4000):
    operations = [
        UpdateOne(
            {"_id": doc["_id"]},
            {"$set": doc},
            upsert=True
        ) for doc in batch
    ]
    
    result = collection.bulk_write(operations)
    print(f"Matched: {result.matched_count}, Inserted: {result.upserted_count}, Modified: {result.modified_count}")
# Out:
# Matched: 0, Inserted: 4, Modified: 0

# %%
from pymongo import UpdateOne


#####
for batch in batchify(doc_list_commence, 4000):
    operations = [
        UpdateOne(
            {"_id": doc["_id"]},
            {"$set": doc},
            upsert=True
        ) for doc in batch
    ]
    
    result = collection.bulk_write(operations)
    print(f"Matched: {result.matched_count}, Inserted: {result.upserted_count}, Modified: {result.modified_count}")
# Out:
# Matched: 1, Inserted: 0, Modified: 1

# %%
from pymongo import UpdateOne


#####
for batch in batchify(doc_list_closed, 4000):
    operations = [
        UpdateOne(
            {"_id": doc["_id"]},
            {"$set": doc},
            upsert=True
        ) for doc in batch
    ]
    
    result = collection.bulk_write(operations)
    print(f"Matched: {result.matched_count}, Inserted: {result.upserted_count}, Modified: {result.modified_count}")
# Out:
# Matched: 1, Inserted: 0, Modified: 1

# %%
from pymongo import UpdateOne


#####
for batch in batchify(doc_list_updated, 4000):
    operations = [
        UpdateOne(
            {"_id": doc["_id"]},
            {"$set": doc},
            upsert=True
        ) for doc in batch
    ]
    
    result = collection.bulk_write(operations)
    print(f"Matched: {result.matched_count}, Inserted: {result.upserted_count}, Modified: {result.modified_count}")
# Out:
# Matched: 4, Inserted: 0, Modified: 4

# %%
client.close()

# %%
from datetime import datetime


datetime.today()
# Out:
# datetime.datetime(2025, 11, 18, 8, 43, 29, 420601)
