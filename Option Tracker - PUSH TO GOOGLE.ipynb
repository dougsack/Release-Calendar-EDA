# %%
## Establish connection to Account
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://dougsack:Ocana2421@cluster1.zdl0b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['InDevelopment']

collection = db['options_tracker']

# %%
docs = collection.find({})

# %%
import pandas as pd

df = pd.DataFrame(docs)

# %%
df
# Out:
#                                                   _id  \
# 0   Nick Weidenfeld_TV_First Look Deal across TV/F...
# 1   Planet of Exile (Book Rights)_TV_Theodore Down...
# 2                   Strangers_TV_Isaac Siegmund-Broka
# 3                FOO Rights Purchase (TA)_Film_Disney
# 4                              Call Me Dad_TV_Viaplay
# ..                                                ...
# 81                      Not Fade Away*_Film_Annapurna
# 82               Edge of Identity_Film_Barbara Bellus
# 83            Edge of Identity_Film_Aviv / New Yorker
# 84                   True American _Film_Rais Bhuiyan
# 85  What Remains of Edith Finch_TV_Annapurna Inter...
#
#    current_option_term_expiration_date_film_ot  \
# 0                                     3/1/2027
# 1                                    2/15/2027
# 2                                   11/22/2026
# 3                                   12/31/2026
# 4                                     6/9/2026
# ..                                         ...
# 81                                   5/31/2022
# 82                                   5/12/2022
# 83                                   5/12/2022
# 84                                   5/11/2022
# 85                                  10/29/2021
#
#                                current_status_film_ot  \
# 0     Extended Term available for 12 months and $575k
# 1   We are on the third option extension, negotiat...
# 2    Studio shall have the right to extend the ini...
# 3   In June 2025, AP paid 380K for 18 month extens...
# 4      We have an option extension $50k for 18 months
# ..                                                ...
# 81  This is Netflix's initial option of the screen...
# 82                                No extensions left.
# 83                                No extensions left.
# 84  Rough date. Assumes 4 months of force majeure ...
# 85  We have an option extension for 18 months for ...
#
#                            dealspecific_notes_film_ot dept_film_ot  \
# 0                                                               TV
# 1   • Expiration of the Second Extension Period fo...           TV
# 2                                                               TV
# 3                                                             Film
# 4        Initial option period is $50k for 18 months.           TV
# ..                                                ...          ...
# 81                                                            Film
# 82                                                            Film
# 83                                                            Film
# 84                                                            Film
# 85                                 Lapsed/Letting Go.           TV
#
#                           dev_id_map  \
# 0                 Nick Weidenfeld_TV
# 1   Planet of Exile (Book Rights)_TV
# 2                       Strangers_TV
# 3      FOO Rights Purchase (TA)_Film
# 4                     Call Me Dad_TV
# ..                               ...
# 81               Not Fade Away*_Film
# 82             Edge of Identity_Film
# 83             Edge of Identity_Film
# 84               True American _Film
# 85    What Remains of Edith Finch_TV
#
#                                 extensions__film_ot  \
# 0
# 1
# 2
# 3
# 4
# ..                                              ...
# 81
# 82
# 83
# 84  $X for XX Months, Appliable vs. non-applicable
# 85
#
#                             initial_option__film_ot  \
# 0
# 1
# 2
# 3
# 4
# ..                                              ...
# 81
# 82
# 83
# 84  $X for XX Months, Appliable vs. non-applicable
# 85
#
#    initial_option_start_date_film_ot option_status_film_ot  \
# 0                           2/1/2025          Initial Term
# 1                           5/4/2023  Additional Extension
# 2                          5/22/2025        Initial Option
# 3                           6/1/2025         2nd Extension
# 4                          12/9/2024        Initial Option
# ..                               ...                   ...
# 81                                                  Lapsed
# 82                        11/13/2020                Lapsed
# 83                        11/13/2020                Lapsed
# 84                                               Purchased
# 85                        10/30/2019
#
#                   project_film_ot purchase_price__film_ot reversion_film_ot  \
# 0                 Nick Weidenfeld
# 1   Planet of Exile (Book Rights)
# 2                       Strangers
# 3        FOO Rights Purchase (TA)
# 4                     Call Me Dad
# ..                            ...                     ...               ...
# 81                 Not Fade Away*
# 82               Edge of Identity
# 83               Edge of Identity
# 84                 True American                    $XXX
# 85    What Remains of Edith Finch
#
#                 rights_holder_film_ot                 type_film_ot
# 0   First Look Deal across TV/FILM/AN              First Look Deal
# 1              Theodore Downes-LeGuin                         Book
# 2                Isaac Siegmund-Broka                  Spec Script
# 3                              Disney                  Concept IP
# 4                             Viaplay                       Format
# ..                                ...                          ...
# 81                          Annapurna                       Script
# 82                     Barbara Bellus            Life Story Rights
# 83                  Aviv / New Yorker  Literary Material (Article)
# 84                       Rais Bhuiyan
# 85              Annapurna Interactive                   Video Game
#
# [86 rows x 15 columns]

# %%
client.close()

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
df[['_id', "project_film_ot"]].to_clipboard()

# %%
data = df[['_id', 'initial_option_start_date_film_ot','option_status_film_ot', 'current_option_term_expiration_date_film_ot', 'current_status_film_ot']]

# %%
data = data.fillna("")

# %%
data = data.set_index("_id")
data = data.reset_index()

# %%
data_export = [data.columns.tolist()] + data.values.tolist()

# %%
data_export
# Out:
# [['_id',
#   'initial_option_start_date_film_ot',
#   'option_status_film_ot',
#   'current_option_term_expiration_date_film_ot',
#   'current_status_film_ot'],
#  ['Nick Weidenfeld_TV_First Look Deal across TV/FILM/AN',
#   '2/1/2025',
#   'Initial Term',
#   '3/1/2027',
#   'Extended Term available for 12 months and $575k'],
#  ['Planet of Exile (Book Rights)_TV_Theodore Downes-LeGuin',
#   '5/4/2023',
#   'Additional Extension',
#   '2/15/2027',
#   'We are on the third option extension, negotiated per the latest amendment. No extensions remaining. '],
#  ['Strangers_TV_Isaac Siegmund-Broka',
#   '5/22/2025',
#   'Initial Option',
#   '11/22/2026',
#   ' Studio shall have the right to extend the initial\n18-month option period by an additional 18-months by payment to Artist of an\nadditional $30K (which amount shall not be applicable against the Script Purchase\nPrice).'],
#  ['FOO Rights Purchase (TA)_Film_Disney',
#   '6/1/2025',
#   '2nd Extension',
#   '12/31/2026',
#   'In June 2025, AP paid 380K for 18 month extension. No extension remaining. Got it back from Disney.'],
#  ['Call Me Dad_TV_Viaplay',
#   '12/9/2024',
#   'Initial Option',
#   '6/9/2026',
#   'We have an option extension $50k for 18 months'],
#  ['Antarctica_Film_Don Hertzfeldt',
#   '4/17/2025',
#   'Initial Option',
#   '10/17/2026',
#   'REMAINING: Extended Option Period. $15k for an additional 6 consecutive* months, if elected by Studio\n(“Extended Option Period”), non-applicable against the Acquisition Fee.'],
#  ['Identical_TV_Scott Turow',
#   '2/27/2025',
#   'Initial Option',
#   '8/27/2026',
#   '(ii) Second Option Period: $35,000 for an additional 18 months (not applicable vs.\nPurchase Price)'],
#  ['Even the Losers_Film_Randy Lanier; A.J. Baime',
#   '6/29/2025',
#   'Initial Option',
#   '7/28/2026',
#   '- Option Extension remaining (12 months @$20k)\n\n- PURCHASE PRICE:  equal to Three Percent (3%) of the final, approved, direct, ingoing, hard cost net budget of the\nPicture (the “Budget,” which excludes completion bond fees, finance charges, interest, contingency\namounts, financing legal fees, and other similar soft costs) less the Initial Option Payment, with a “floor”\nof Two Hundred Sixty-Five Thousand United States Dollars (US$265,000) and a “ceiling” of Six Hundred\nUnited States Dollars (US$600,000).'],
#  ['Aztec_TV_Estate of Gary Jennings',
#   '1/22/2025',
#   'Initial Option',
#   '7/22/2026',
#   'Second Option Period: $50k for additional 18 months (not applicable vs.\nPurchase Price).'],
#  ['The Hot Kid; Up In Honey’s Room_TV_Peter Leonard/ Elmore Leonard',
#   '4/13/2023',
#   'Initial Option',
#   '10/22/2026',
#   'We have a Second Option Period: $50k for additional 18 months'],
#  ['Seized_TV_Max Hardberger',
#   '12/9/2024',
#   'Initial Option',
#   '6/9/2026',
#   'Second Option Period: $50k for additional 18 months (not applicable vs. Purchase Price).'],
#  ['Finding Gobi_Film_Dion Leonard',
#   '12/6/2024',
#   'Initial Option',
#   '6/5/2026',
#   'Second Option Period Consideration: of\nSeventeen Thousand Five Hundred Dollars ($17,500) for an additional 18 months.'],
#  ['Norco 80_Film_Fifth Season',
#   '5/11/2025',
#   '1st Extension',
#   '5/11/2026',
#   'Fifth Season owns the option'],
#  ['Unt. Mallory Proj._TV_Ian Park',
#   '1/5/2021',
#   'Initial Option, 1st Extension',
#   '1/12/2026',
#   'No extensions left.'],
#  ['Everything I Never Told You_TV_Celeste Ng',
#   '3/24/2022',
#   'Additional Extension',
#   '12/31/2025',
#   'No extensions remaining.'],
#  ['Five Hitmen_Film_The Guardian',
#   '6/18/2024',
#   'Initial Option',
#   '12/18/2025',
#   'Initial option: $10K for 18 months. Option extension: $10K for 18 months. AGREEMENT TERMS CLOSED.'],
#  ['Who is Maud Dixon_TV_Alexandra Andrews Beha',
#   '6/12/2024',
#   'Initial Option',
#   '12/11/2025',
#   ''],
#  ['Made in Utah_TV_Hikari',
#   '7/1/2022',
#   'Paused',
#   '4/1/2026',
#   'We have an option extension for 12 months for $10,000.'],
#  ['SYD (TA)_Film_', '7/30/2024', 'T.A', '1/30/2026', ''],
#  ['Sapiens_TV_Yuval Noah Harari (Sapienship)',
#   '9/12/2024',
#   'Initial Option',
#   '3/12/2026',
#   ''],
#  ['Twelve Minutes_Film_Nomada',
#   '8/8/2022',
#   'Initial Option',
#   '2/17/2026',
#   'On Option Extension. No further extensions contemplated in the deal.'],
#  ['Operator_TV_Asja Bakic (Rights)',
#   '10/22/2024',
#   'Initial Option',
#   '4/22/2026',
#   'Second Option Period:  $12.5k for additional 18 months (not applicable vs. Purchase Price).'],
#  ['Belly of the Beast _Film_Jerome Loving',
#   '3/1/2025',
#   'Initial Option',
#   '3/1/2026',
#   '- Option Extension remaining (12 months @$20k)\n\n- PURCHASE PRICE:  equal to Three Percent (3%) of the final, approved, direct, ingoing, hard cost net budget of the\nPicture (the “Budget,” which excludes completion bond fees, finance charges, interest, contingency\namounts, financing legal fees, and other similar soft costs) less the Initial Option Payment, with a “floor”\nof Two Hundred Sixty-Five Thousand United States Dollars (US$265,000) and a “ceiling” of Six Hundred\nUnited States Dollars (US$600,000).'],
#  ['Chef_Film_Michael Arndt',
#   '6/24/2024',
#   'Collaboration Period, 1st Extension',
#   '1/31/2026',
#   '9 month collaboration period. We extended an additional 6 months. '],
#  ['Mental Health Day_Film_Jason Mossberg',
#   '5/3/2024',
#   'Lapsed',
#   '11/3/2025',
#   'Abandoning the project.'],
#  ['Planet of Exile (Script Rights)_TV_Daniel Stiepleman (via Ursula Le Guin)',
#   '4/24/2023',
#   'Additional Extension',
#   '8/23/2025',
#   'Second Option Period for 18 months available with contingencies.'],
#  ['The Dead Thing_TV_Paul Tremblay',
#   '1/17/2024',
#   'Initial Option',
#   '7/17/2025',
#   'we have a second option period: $12.5k for an additional 18 months'],
#  ['Hitchhiker_Film_Dan Ast',
#   '5/1/2023',
#   'Lapsed',
#   '5/10/2025',
#   'Initial Option runs through and including October 31, 2024. First Option Extension available for 18-months, for $15,000'],
#  ['Who is Maud Dixon (First Position)_TV_Boo Killebrew',
#   '3/28/2025',
#   'Initial Term',
#   '10/16/2025',
#   ''],
#  ['Chelsea Barnard Consulting Agreement_Film_',
#   '10/21/2024',
#   'Initial Term',
#   '10/10/2025',
#   'This is Chelsea Barnard’s consulting agreement'],
#  ['Neverworld Wake_TV_Marisha Pessl',
#   '1/1/2023',
#   'Lapsed',
#   '5/31/2025',
#   'We have a second option period (18 months). This current date takes into account a gratis extension we received.'],
#  ['Press Your Luck_Film_Christopher Cantwell',
#   '5/1/2023',
#   'Lapsed',
#   '5/10/2025',
#   'Second Option Period: 18months for 30k. Letting go.'],
#  ['Operator (Pilot Script)_TV_Victoria Bata',
#   '10/21/2024',
#   'Initial Option',
#   '10/21/2025',
#   'We have an extension for 12 months and $45k'],
#  ['Legend of Georgia McBride_Film_Matthew Lopez',
#   '4/1/2025',
#   'Initial Option',
#   '10/1/2025',
#   ''],
#  ['Grant & Sherman_Film_Katherine Flood',
#   '1/1/2024',
#   'Initial Option',
#   '9/20/2025',
#   'Second option period: 5K for 18 months'],
#  ['Sia Martinez_TV_Raquel Gilliland',
#   '4/8/2021',
#   'Additional Extension',
#   '4/14/2025',
#   'No extensions left.'],
#  ['Amberville_TV_', '', 'Lapsed', '7/28/2024', ''],
#  ['Waves_Film_Steinkis Groupe/Ingrid Chabbert',
#   '6/29/2022',
#   'Lapsed',
#   '7/6/2024',
#   'CP’s satisfied June 29, 2022. 18 month option, with another 18 month extension available for 5,000 Euro'],
#  ['We Are Little Zombies_TV_Dentsu',
#   '5/23/2022',
#   'Lapsed',
#   '5/30/2024',
#   '6 month extension remains. 10K. We are letting this go.'],
#  ['Unt. Pozner Project_Film_Leonard Pozner',
#   '1/19/2023',
#   '',
#   '1/25/2025',
#   'No extensions left. Current pushback on FM notice. 7/18/24 is lapse if FM extension isn’t accepted.'],
#  ['Unt. Pozner Project_Film_Veronique De La Rosa / Leonard Pozner',
#   '1/19/2023',
#   'Lapsed',
#   '12/13/2024',
#   'No extensions left. 1/25/25 with 191 days added for both strikes'],
#  ['Lucky Girl_Film_Ari Katcher & Ryan Welsh',
#   '8/13/2021',
#   'Lapsed',
#   '9/11/2024',
#   'No extensions left. Per Jack email on 1/26/22: Option extension was paid via Valparaiso. Per CC’s email 8.12, extension runs until 10/16/22'],
#  ['Superbloom_Film_Leah Rachel',
#   '5/3/2022',
#   'Purchased',
#   '1/20/2025',
#   'If there’s been “significant development” of Picture during Initial Option Period. Then can extend the Initial Option Period for an additional six (6) month period. Rights to lapse on 7/13/24 + 191 days for extension'],
#  ['The Silent Patient_Film_Alex Michaelides',
#   '3/14/2022',
#   'Purchased',
#   '12/20/2024',
#   'Purchased'],
#  ['The Isle of Youth_Film_Laura van den Berg// Matthew Capodicasa',
#   '3/7/2022',
#   'Lapsed',
#   '3/15/2024',
#   'We are letting this go.'],
#  ['Project Heron (Julia’s writing term)_TV_Julia Pott (Cross Media)',
#   '2/12/2024',
#   'Lapsed',
#   '4/3/2024',
#   ''],
#  ['Cure for Cancer (Book Rights)_TV_Lisa Taddeo',
#   '2/2/2022',
#   'Lapsed',
#   '2/8/2024',
#   'No extensions left.'],
#  ['Artful Escape (Attachment)_TV_', '2/8/2023', 'Lapsed', '2/7/2024', ''],
#  ['Unt. Pozner Project - Sandy Hook Book_Film_Elizabeth Williamson',
#   '1/24/2022',
#   '',
#   '1/30/2024',
#   'We have an option extension for 12 months for $45,000.'],
#  ['War on Christmas_TV_The Inlander',
#   '5/11/2022',
#   'Lapsed',
#   '5/9/2024',
#   'Sixth option extension remaining (5k for 12 months). We are letting this go.'],
#  ['STAGS_TV_MA Bennet',
#   '4/15/2021',
#   'Lapsed',
#   '4/15/2024',
#   'We are letting this go.'],
#  ['CHANGELING ACTOR_TV_', '', 'Lapsed', '2/17/2024', ''],
#  ['Cure for Cancer (Bible & Script)_TV_Lisa Taddeo',
#   '12/20/2020',
#   'Lapsed',
#   '2/8/2024',
#   ''],
#  ['Nightbitch_Film_Rachel Yoder',
#   '4/25/2022',
#   'Purchased',
#   '10/24/2023',
#   'No extensions left. We’ve purchased.'],
#  ['Zankou Chicken Murders_TV_Wondery',
#   '12/9/2021',
#   'Lapsed',
#   '12/9/2022',
#   'No extensions left. (With Starz)'],
#  ['Empath_TV_Megan Pohlmann',
#   '6/1/2021',
#   'Lapsed',
#   '12/1/2022',
#   'We have an option extension for 18 months'],
#  ["They Don't Come Home Anymore_Film_T.E Grau",
#   '12/21/2021',
#   'Lapsed',
#   '12/29/2023',
#   'No extensions left. Letting go.'],
#  ['Hidden Room_TV_Stella Duffy',
#   '6/14/2021',
#   'Lapsed',
#   '12/21/2023',
#   'No extensions left.'],
#  ['FOO Wedge Deal Development Period_Film_',
#   '3/6/2023',
#   '',
#   '9/18/2023',
#   'Min/Max:\n- Minimum (28 weeks from start date) would end September 18th, 2023 (9/18/23)\n- Maximum (32 weeks from start date) would end on October 16th, 2023 (10/16/23)'],
#  ['Unt Kevin James Thornton Project_Film_Kevin James Thornton',
#   '12/16/2021',
#   'Lapsed',
#   '6/16/2023',
#   'Letting go.'],
#  ['Planet of Exile (Book Rights)_TV_Theodore Le Guin',
#   '',
#   'Additional Extension',
#   '5/4/2023',
#   ''],
#  ['True American Reversion_Film_',
#   '',
#   'Purchased',
#   '4/14/2023',
#   '30 day extension gratis from March 15th, 2023.'],
#  ['Important Artifacts_Film_New Regency',
#   '5/17/2021',
#   'Lapsed',
#   '11/17/2022',
#   'No extensions left.'],
#  ['Bear: The Life and Times of Augustus Owsley Stanley III_Film_Robert Greenfield',
#   '10/19/2021',
#   'Lapsed',
#   '11/20/2023',
#   'We have a Second Option Period of 15k USD for an additional 18 months. We are letting this go.'],
#  ['The Preppy Handbook_TV_Lisa Birnbach',
#   '1/20/2022',
#   'Lapsed',
#   '1/20/2023',
#   'No extensions left.'],
#  ['Psychodrama_TV_Drama Republic Ltd',
#   '5/15/2020',
#   'Lapsed',
#   '11/15/2022',
#   'No extensions left.'],
#  ['The Dream_TV_Stitcher',
#   '10/28/2021',
#   'Lapsed',
#   '10/28/2022',
#   'No extensions left.'],
#  ['Important Artifacts_Film_Leanne Shapton',
#   '4/1/2021',
#   'Lapsed',
#   '10/1/2022',
#   'No extensions left.'],
#  ['Necessary People_TV_Anna Pitoniak',
#   '3/17/2022',
#   'Lapsed',
#   '9/17/2022',
#   'No extensions left.'],
#  ['Blood Sugar_TV_Preston Thompson and Duke Merriman',
#   '4/22/2022',
#   'Lapsed',
#   '10/22/2022',
#   'No extensions left. (option with HBO)'],
#  ['Who Killed Tulum?_TV_NY Mag',
#   '9/16/2021',
#   'Lapsed',
#   '9/16/2022',
#   'Amazon took over and negotiated this second option extension.'],
#  ['Hacker is Watching_TV_David Kushner',
#   '3/6/2021',
#   'Lapsed',
#   '9/6/2022',
#   'No extensions left.'],
#  ['Unt. Coretta Scott King_TV_Treehouse Pictures LLC',
#   '10/13/2020',
#   'Lapsed',
#   '10/13/2022',
#   'No extensions left.'],
#  ['Exile_TV_Rose Cartwright', '3/31/2021', 'Lapsed', '10/1/2022', ''],
#  ['Animal Husbandry_TV_Noah Prestwich',
#   '5/18/2022',
#   'Lapsed',
#   '8/18/2022',
#   'We have pro-rata monthly extensions remaining.'],
#  ['The Echo Wife_Film_Sarah Gailey',
#   '2/11/2021',
#   'Lapsed',
#   '8/11/2022',
#   'We have an option extension for 18 months for $50,000. We let lapse'],
#  ['Assassination of B.W Spurge_Film_Yelchin and Anderson',
#   '8/4/2021',
#   'Lapsed',
#   '8/4/2022',
#   'We have no more options left.'],
#  ['The Power Company_TV_Nick Von Keller',
#   '1/25/2021',
#   'Lapsed',
#   '7/25/2022',
#   'No extensions left.'],
#  ['Burn the Place_TV_Iliana Regan',
#   '6/8/2021',
#   'Lapsed',
#   '6/7/2022',
#   'No extensions left.'],
#  ['Unt. Death Doula_TV_Alua Arthur',
#   '6/16/2021',
#   'Lapsed',
#   '6/15/2022',
#   'We have an option extension for 12 months for $25,000'],
#  ['LAT Twins Article_TV_Barbara Demick',
#   '3/8/2022',
#   'Lapsed',
#   '6/6/2022',
#   'We have a third option extension for 3 months for $8,750 until 9/5/2022.'],
#  ['Not Fade Away*_Film_Annapurna',
#   '',
#   'Lapsed',
#   '5/31/2022',
#   "This is Netflix's initial option of the screenplay that we own"],
#  ['Edge of Identity_Film_Barbara Bellus',
#   '11/13/2020',
#   'Lapsed',
#   '5/12/2022',
#   'No extensions left.'],
#  ['Edge of Identity_Film_Aviv / New Yorker',
#   '11/13/2020',
#   'Lapsed',
#   '5/12/2022',
#   'No extensions left.'],
#  ['True American _Film_Rais Bhuiyan',
#   '',
#   'Purchased',
#   '5/11/2022',
#   'Rough date. Assumes 4 months of force majeure due to COVID'],
#  ['What Remains of Edith Finch_TV_Annapurna Interactive',
#   '10/30/2019',
#   '',
#   '10/29/2021',
#   'We have an option extension for 18 months for $25,000']]

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Step 1: Define the scope
scope = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive",
]

# Step 2: Load credentials
creds = ServiceAccountCredentials.from_json_keyfile_name("ultra-sound-463216-c2-0e076e5f88fe.json", scope)

# Step 3: Authorize and connect
client = gspread.authorize(creds)

# Step 4: Open sheet by URL
sheet_url = "https://docs.google.com/spreadsheets/d/1PaAQEAJcTupLNgvTLaawyWPKOfIrUFAQf-WiUnZMbxY/edit?gid=25505532#gid=25505532"
spreadsheet = client.open_by_url(sheet_url)

# Optional: Access specific sheet/tab
sheet = spreadsheet.worksheet("options_expirations")  # or spreadsheet.worksheet("SheetName")

# %%
# Example: Read data
sheet.clear()
# Out:
# {'spreadsheetId': '1PaAQEAJcTupLNgvTLaawyWPKOfIrUFAQf-WiUnZMbxY',
#  'clearedRange': 'options_expirations!A1:Z1000'}

# %%
sheet.update(data_export)
# Out:
# {'spreadsheetId': '1PaAQEAJcTupLNgvTLaawyWPKOfIrUFAQf-WiUnZMbxY',
#  'updatedRange': 'options_expirations!A1:E87',
#  'updatedRows': 87,
#  'updatedColumns': 5,
#  'updatedCells': 435}
