# %% [raw]
# https://docs.google.com/spreadsheets/d/1PaAQEAJcTupLNgvTLaawyWPKOfIrUFAQf-WiUnZMbxY/edit?gid=25505532#gid=25505532

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Step 1: Define the scope
scope = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive",
]

# Step 2: Load credentials
creds = ServiceAccountCredentials.from_json_keyfile_name("ultra-sound-463216-c2-0e076e5f88fe.json", scope)

# Step 3: Authorize and connect
client = gspread.authorize(creds)

# Step 4: Open sheet by URL
sheet_url = "https://docs.google.com/spreadsheets/d/1PaAQEAJcTupLNgvTLaawyWPKOfIrUFAQf-WiUnZMbxY/edit?gid=25505532#gid=25505532"
spreadsheet = client.open_by_url(sheet_url)

# Optional: Access specific sheet/tab
sheet = spreadsheet.worksheet("Linear Project List")  # or spreadsheet.worksheet("SheetName")

# Example: Read data
data = sheet.get_all_records(head=1)

# %%
import pandas as pd

df = pd.DataFrame(data)

# %% [raw]
# import pandas as pd
#
# df = pd.read_csv("Project Directory - Project List.csv") ## Temporary

# %%
df
# Out:
#                              Title Project ID  \
# 0                       ANTARCTICA
# 1                              FOO  814974530
# 2                          MOOMINS
# 3           SOME ASSEMBLY REQUIRED
# 4    THE BROBARIANS (FKA MANTOOTH)
# ..                             ...        ...
# 961
# 962
# 963
# 964
# 965
#
#                                         Underlying IP  \
# 0
# 1
# 2    The world and characters of the Moomin franchise
# 3
# 4
# ..                                                ...
# 961
# 962
# 963
# 964
# 965
#
#                                                Logline      AP DIVISION  \
# 0    A darkly funny, horrific, and surreal feature-...  Animation, Film
# 1    A feature-length animation film that follows F...  Animation, Film
# 2    Animated adaptation of the books by Tove Jansson.  Animation, Film
# 3    Jack, an orphan from the streets of London, ha...  Animation, Film
# 4    To protect his tribe, stop a war, and save a l...  Animation, Film
# ...

# %%
df['Title'] = df['Title'].astype(str).str.strip()

# %%
df = df[df['Title'] != ""]

# %%
df
# Out:
#                              Title Project ID  \
# 0                       ANTARCTICA
# 1                              FOO  814974530
# 2                          MOOMINS
# 3           SOME ASSEMBLY REQUIRED
# 4    THE BROBARIANS (FKA MANTOOTH)
# ..                             ...        ...
# 209                  THE STAIRCASE
# 210  THE BALLARD OF BUSTER SCRUGGS
# 211                      ALAN WAKE  905490123
# 212                        CONTROL  857708672
# 213  EDITH FINCH (WHAT REMAINS OF)
#
#                                         Underlying IP  \
# 0
# 1
# 2    The world and characters of the Moomin franchise
# 3
# 4
# ..                                                ...
# 209
# 210
# 211
# 212
# 213
#
#                                                Logline      AP DIVISION  \
# 0    A darkly funny, horrific, and surreal feature-...  Animation, Film
# 1    A feature-length animation film that follows F...  Animation, Film
# ...

# %%
df.columns = (
    df.columns
      .str.lower()
      .str.strip()
      .str.replace(r"\s+", "_", regex=True)   # spaces -> underscore
      .str.replace(r"[^0-9a-zA-Z_]", "", regex=True)  # optional: remove weird chars
      + "_directory"
)

# %%
df = df.rename({"title_directory":"_id"}, axis=1)

# %%
df.columns.to_list()
# Out:
# ['_id',
#  'project_id_directory',
#  'underlying_ip_directory',
#  'logline_directory',
#  'ap_division_directory',
#  'priority_title_directory',
#  'project_stage_directory',
#  'ap_lead_directory',
#  'ap_producer_directory',
#  'ap_jr_directory',
#  'ap_dev_directory',
#  'ap_admin_directory',
#  'slack_channel_directory',
#  'creator_id_directory',
#  'creator_name_directory',
#  'lead_creative_directorshowrunnerdeveloper_attached_directory',
#  'talent_attached_directory',
#  'start_of_development_directory',
#  'release_date_directory',
#  'dev_tracker_id_directory',
#  'remaining_committed_directory',
#  'total_cost_with_committments_directory',
#  'itd_current_year_directory',
#  'options_tracker_id_directory',
#  'initial_option_start_date_film_ot_directory',
#  'option_status_film_ot_directory',
#  'current_option_term_expiration_date_film_ot_directory',
#  'current_status_film_ot_directory']

# %%
cols = [
    '_id',
 'project_id_directory',
    'priority_title_directory',
 'underlying_ip_directory',
 'logline_directory',
 'ap_division_directory',
 'project_stage_directory',
 'ap_lead_directory',
 'ap_producer_directory',
 'ap_jr_directory',
 'ap_dev_directory',
 'ap_admin_directory',
 'slack_channel_directory',
 'creator_id_directory',
 'creator_name_directory',
 'lead_creative_directorshowrunnerdeveloper_attached_directory',
 'talent_attached_directory',
 'start_of_development_directory',
 'release_date_directory',

    'dev_tracker_id_directory',
 'remaining_committed_directory',
 'total_cost_with_committments_directory',
 'itd_current_year_directory',
 'options_tracker_id_directory',
# 'initial_option_start_date_film_ot_directory',
 'option_status_film_ot_directory',
 #'current_option_term_expiration_date_film_ot_directory',
 'current_status_film_ot_directory'
       ]

# %%
float_cols = [
    "remaining_committed_directory",
    "total_cost_with_committments_directory",
    "itd_current_year_directory",
]

df[float_cols] = (
    df[float_cols]
    .replace(r"[\$,]", "", regex=True)
    .replace("", None)
    .astype(float)
)

# %%
df["initial_option_start_date_film_ot_directory"] = pd.to_datetime(df["initial_option_start_date_film_ot_directory"])
df["current_option_term_expiration_date_film_ot_directory"] = pd.to_datetime(df["current_option_term_expiration_date_film_ot_directory"])

# %%
df["ap_lead_directory"] = df["ap_lead_directory"].fillna("")
df["ap_jr_directory"] = df["ap_jr_directory"].fillna("")
df["ap_dev_directory"] = df["ap_dev_directory"].fillna("")
df["ap_admin_directory"] = df["ap_admin_directory"].fillna("")
df["ap_division_directory"] = df["ap_division_directory"].fillna("")

# %%
#df["project_stage_film_pt"] = df["project_stage_film_pt"].str.split(",").apply(lambda x: [i.strip() for i in x])
df["ap_lead_directory"] = df["ap_lead_directory"].str.split(",").apply(lambda x: [i.strip() for i in x])
df["ap_jr_directory"] = df["ap_jr_directory"].str.split(",").apply(lambda x: [i.strip() for i in x])
df["ap_dev_directory"] = df["ap_dev_directory"].str.split(",").apply(lambda x: [i.strip() for i in x])
df["ap_admin_directory"] = df["ap_admin_directory"].str.split(",").apply(lambda x: [i.strip() for i in x])
df["ap_division_directory"] = df["ap_division_directory"].str.split(",").apply(lambda x: [i.strip() for i in x])

# %%
title_map = {
    "Even The Losers (Fka Need For Weed)": "Even the Losers",
    "Belly Of The Beast": "Belly of The Beast",
    'Brady Corbet / Mona Fastvold Project (Unt.)': "Origin of the World fka Unt. Brady Corbet & Mona Fastvold Project",

    'Silent Patient, The ': "The Silent Patient",
    '12 Minutes (Film)': "12 Minutes",
    'Bennett Miller (Unt.) ':"Unt. Bennett Miller",
    
    'Nicole Taylor Idea (Unt.)':"Evie Mcbrayne fka Unt. Nicole Taylor",
    'James Sweeney (Unt.)':"Unt. James Sweeney",
    'Into The Glory Whole':"Into the Glory whole",
    'Legend Of Georgia Mcbride, The ':"The Legend of Georgia McBride",

        'Lost Wild, The ':"The Lost Wild",


        'Beast Fiction Project (Unt.)':"Unt. Beast Fiction Project",

            'Ann Lee (Fka The Woman Clothed By The Sun) ':"The Testament of Ann Lee",



    # add more…
}

df['_id'] = df['_id'].replace(title_map)

# %%
df['_id'] = df["_id"].str.title()

# %%
df.query("_id=='The Invite'")
# Out:
#            _id project_id_directory underlying_ip_directory  \
# 23  The Invite            828769775
#
#                                     logline_directory ap_division_directory  \
# 23  A wild night ensues when one couple invites th...                [Film]
#
#    priority_title_directory project_stage_directory ap_lead_directory  \
# 23                    FALSE         1. Post, 1. GTM  [Megan, Chelsea]
#
#    ap_producer_directory ap_jr_directory  ... release_date_directory  \
# 23                                [Alex]  ...              6/26/2026
#
#    dev_tracker_id_directory remaining_committed_directory  \
# 23                                                    0.0
#
#    total_cost_with_committments_directory itd_current_year_directory  \
# 23                                    0.0                        0.0
#
#    options_tracker_id_directory initial_option_start_date_film_ot_directory  \
# 23                                                                      NaT
#
# ...

# %%
df.head().columns
# Out:
# Index(['_id', 'project_id_directory', 'underlying_ip_directory',
#        'logline_directory', 'ap_division_directory',
#        'priority_title_directory', 'project_stage_directory',
#        'ap_lead_directory', 'ap_producer_directory', 'ap_jr_directory',
#        'ap_dev_directory', 'ap_admin_directory', 'slack_channel_directory',
#        'creator_id_directory', 'creator_name_directory',
#        'lead_creative_directorshowrunnerdeveloper_attached_directory',
#        'talent_attached_directory', 'start_of_development_directory',
#        'release_date_directory', 'dev_tracker_id_directory',
#        'remaining_committed_directory',
#        'total_cost_with_committments_directory', 'itd_current_year_directory',
#        'options_tracker_id_directory',
#        'initial_option_start_date_film_ot_directory',
#        'option_status_film_ot_directory',
#        'current_option_term_expiration_date_film_ot_directory',
#        'current_status_film_ot_directory'],
# ...

# %%
df.tail().to_clipboard()

# %% [raw]
# alias_cols = ['imdb_id', 'tmdb_id', 'igdb_id',
#        'steam_id', 'dev_tracker_id', 'indie_bi_product_name']

# %% [raw]
# df[alias_cols] = pd.NA

# %% [raw]
# df["aliases"] = df[alias_cols].to_dict(orient="records")

# %% [raw]
# df = df.drop(alias_cols, axis=1)

# %%
date_df = df[['_id', 'initial_option_start_date_film_ot_directory', 'current_option_term_expiration_date_film_ot_directory']].dropna()

# %%
df = df[cols]

# %%
df.columns
# Out:
# Index(['_id', 'project_id_directory', 'priority_title_directory',
#        'underlying_ip_directory', 'logline_directory', 'ap_division_directory',
#        'project_stage_directory', 'ap_lead_directory', 'ap_producer_directory',
#        'ap_jr_directory', 'ap_dev_directory', 'ap_admin_directory',
#        'slack_channel_directory', 'creator_id_directory',
#        'creator_name_directory',
#        'lead_creative_directorshowrunnerdeveloper_attached_directory',
#        'talent_attached_directory', 'start_of_development_directory',
#        'release_date_directory', 'dev_tracker_id_directory',
#        'remaining_committed_directory',
#        'total_cost_with_committments_directory', 'itd_current_year_directory',
#        'options_tracker_id_directory', 'option_status_film_ot_directory',
#        'current_status_film_ot_directory'],
#       dtype='object')

# %%
from datetime import datetime

df['update_date'] = datetime.today()

# %%
data = df.to_dict(orient='records')

# %%
date_data = date_df.to_dict(orient='records')

# %%
date_data
# Out:
# [{'_id': 'Antarctica',
#   'initial_option_start_date_film_ot_directory': Timestamp('2025-04-17 00:00:00'),
#   'current_option_term_expiration_date_film_ot_directory': Timestamp('2026-10-17 00:00:00')},
#  {'_id': 'Foo',
#   'initial_option_start_date_film_ot_directory': Timestamp('2025-06-01 00:00:00'),
#   'current_option_term_expiration_date_film_ot_directory': Timestamp('2026-12-31 00:00:00')},
#  {'_id': 'Belly Of The Beast',
#   'initial_option_start_date_film_ot_directory': Timestamp('2025-03-01 00:00:00'),
#   'current_option_term_expiration_date_film_ot_directory': Timestamp('2026-03-01 00:00:00')},
#  {'_id': 'Even The Losers (Fka Need For Weed)',
#   'initial_option_start_date_film_ot_directory': Timestamp('2025-06-29 00:00:00'),
#   'current_option_term_expiration_date_film_ot_directory': Timestamp('2026-07-28 00:00:00')},
#  {'_id': 'Legend Of Georgia Mcbride, The',
#   'initial_option_start_date_film_ot_directory': Timestamp('2025-04-01 00:00:00'),
# ...

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
## Establish connection to Account
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://dougsack:Ocana2421@cluster1.zdl0b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['InDevelopment']

collection = db['project_directory']

# %%
def batchify(data, batch_size):
    for i in range(0, len(data), batch_size):
        yield data[i:i + batch_size]

# %% [raw]
# collection.delete_many({})

# %%
from pymongo import UpdateOne


#####
for batch in batchify(data, 4000):
    operations = [
        UpdateOne(
            {"_id": doc["_id"]},
            {"$set": doc},
            upsert=True
        ) for doc in batch
    ]
    
    result = collection.bulk_write(operations)
    print(f"Matched: {result.matched_count}, Inserted: {result.upserted_count}, Modified: {result.modified_count}")
# Out:
# Matched: 214, Inserted: 0, Modified: 214

# %%
from pymongo import UpdateOne


#####
for batch in batchify(date_data, 4000):
    operations = [
        UpdateOne(
            {"_id": doc["_id"]},
            {"$set": doc},
            upsert=True
        ) for doc in batch
    ]
    
    result = collection.bulk_write(operations)
    print(f"Matched: {result.matched_count}, Inserted: {result.upserted_count}, Modified: {result.modified_count}")
# Out:
# Matched: 13, Inserted: 0, Modified: 0

# %%
from datetime import datetime


datetime.today()
# Out:
# datetime.datetime(2026, 3, 9, 13, 5, 36, 606814)

# %%
client.close()
