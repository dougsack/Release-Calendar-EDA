# %%
import pandas as pd
## Establish connection to Account
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://dougsack:Ocana2421@cluster1.zdl0b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['project_evaluations']

collection = db['movies']

# %%
query = {
    "release_date": {"$gt": "2025-10-06"},
    'origin_country': {"$in":['US']}
 


}

# %%
projection = {"title":1, 'budget':1, 'revenue':1, 'release_date':1, 'update_date':1}

# %%
from datetime import datetime

query_docs = collection.find(query, projection)

# %%
df = pd.DataFrame(query_docs)

# %%
df.sort_values("release_date").head(50)
# Out:
#             _id                                 title       budget   revenue  \
# 208  tt33335602                  Maintenance Required          0.0       0.0
# 71    tt4627382                               Roofman          0.0       0.0
# 10    tt6604188                            TRON: Ares  150000000.0       0.0
# 2    tt30400277              Kiss of the Spider Woman   30000000.0       0.0
# 69   tt32159989                        After the Hunt          0.0       0.0
# 146   tt7130300                 The Woman in Cabin 10          0.0       0.0
# 183  tt33980854                             Your Host          0.0       0.0
# 212  tt36454258             A Wisconsin Christmas Pie          0.0       0.0
# 83   tt28078628                          Soul on Fire        111.0       0.0
# 20   tt18382850            If I Had Legs I'd Kick You          0.0       0.0
# 170  tt33996087                          Deathstalker          0.0       0.0
# 3    tt34962891                  The Perfect Neighbor          0.0       0.0
# 195  tt37439608          Marilyn Minter: Pretty/Dirty          0.0       0.0
# 93   tt34688195                               Couture          0.0       0.0
# 207  tt35495052                   The Family McMullen          0.0       0.0
# 164  tt33311244                             Our Fault          0.0       0.0
# 26   tt29644189                         Black Phone 2          0.0       0.0
# 80    tt8667404               The Chronology of Water          0.0       0.0
# 0    tt27543578                          Good Fortune          0.0       0.0
# 213  tt13968662                    A Magnificent Life   15000000.0       0.0
# 194  tt34379050                   Night of the Reaper          0.0  750000.0
# 85   tt33455099                        The Mastermind          0.0       0.0
# 173   tt9817924                           The Taverna          0.0       0.0
# 97   tt14830912                     The Lost Princess          0.0       0.0
# 205  tt31425731                              Playdate          0.0       0.0
# 188  tt21825416                       Truth & Treason          0.0       0.0
# 114   tt1312221                          Frankenstein  120000000.0       0.0
# 176  tt37674658      Stiller & Meara: Nothing Is Lost          0.0       0.0
# 37   tt32536315                             Blue Moon          0.0       0.0
# 203  tt36364046             A Royal Montana Christmas          0.0       0.0
# 180  tt33502160        The Hand That Rocks the Cradle          0.0       0.0
# 102  tt31923069  Springsteen: Deliver Me from Nowhere          0.0       0.0
# 123  tt27953589                                 Hedda          0.0       0.0
# 19   tt12300742                               Bugonia          0.0       0.0
# 201  tt36214705           Once Upon A Christmas Crown          0.0       0.0
# 13   tt27977862                             Last Days          0.0       0.0
# 163  tt32647448                          In Our Blood          0.0       0.0
# 209  tt32314672                      Under the Lights          0.0       0.0
# 139  tt12583926                           Anniversary          0.0       0.0
# 127  tt37028491                               Step 10        200.0       0.0
# 130  tt21616352                   A Blood Moon Rising          0.0       0.0
# 168   tt3015054                             The Juice          0.0       0.0
# 192  tt36392525             Le Disque Orange Brillant          0.0       0.0
# 65    tt3712038                                  Hyde      10000.0       0.0
# 153  tt36386809                          Race/America      50000.0       0.0
# 149  tt17497960            BLKNWS: Terms & Conditions          0.0       0.0
# 56   tt31227572                    Predator: Badlands          0.0       0.0
# 14   tt14107334                       The Running Man          0.0       0.0
# 118  tt29567915                             Nuremberg          0.0       0.0
# 39   tt29768334                          Train Dreams   10000000.0       0.0
#
#     release_date update_date
# 208   2025-10-07  2025-10-06
# 71    2025-10-08  2025-10-06
# 10    2025-10-08  2025-10-06
# 2     2025-10-09  2025-10-06
# 69    2025-10-09  2025-10-06
# 146   2025-10-09  2025-10-06
# 183   2025-10-09  2025-10-06
# 212   2025-10-09  2025-10-06
# 83    2025-10-10  2025-10-06
# 20    2025-10-10  2025-10-06
# 170   2025-10-10  2025-10-06
# 3     2025-10-10  2025-10-06
# 195   2025-10-11  2025-10-06
# 93    2025-10-15  2025-10-06
# 207   2025-10-15  2025-10-06
# 164   2025-10-15  2025-10-06
# 26    2025-10-15  2025-10-06
# 80    2025-10-15  2025-10-06
# 0     2025-10-15  2025-10-06
# 213   2025-10-15  2025-10-06
# 194   2025-10-16  2025-10-06
# 85    2025-10-16  2025-10-06
# 173   2025-10-16  2025-10-06
# 97    2025-10-16  2025-10-06
# 205   2025-10-16  2025-10-06
# 188   2025-10-17  2025-10-06
# 114   2025-10-17  2025-10-06
# 176   2025-10-17  2025-10-06
# 37    2025-10-17  2025-10-06
# 203   2025-10-18  2025-10-06
# 180   2025-10-21  2025-10-06
# 102   2025-10-22  2025-10-06
# 123   2025-10-22  2025-10-06
# 19    2025-10-23  2025-10-06
# 201   2025-10-23  2025-10-06
# 13    2025-10-24  2025-10-06
# 163   2025-10-24  2025-10-06
# 209   2025-10-25  2025-10-06
# 139   2025-10-29  2025-10-06
# 127   2025-10-31  2025-10-06
# 130   2025-10-31  2025-10-06
# 168   2025-10-31  2025-10-06
# 192   2025-10-31  2025-10-06
# 65    2025-11-01         NaT
# 153   2025-11-01  2025-10-06
# 149   2025-11-02  2025-10-06
# 56    2025-11-05  2025-10-06
# 14    2025-11-05  2025-10-06
# 118   2025-11-06  2025-10-06
# 39    2025-11-06  2025-10-06
