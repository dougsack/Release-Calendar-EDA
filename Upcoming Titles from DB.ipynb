# %%
import pandas as pd
## Establish connection to Account
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://dougsack:Ocana2421@cluster1.zdl0b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['project_evaluations']

collection = db['movies']

# %%
from datetime import datetime

query_docs = collection.find({
    "release_date": {"$gt": "2025-09-09"},
 


})

# %%
df = pd.DataFrame(query_docs)

# %%
df.sort_values("release_date").to_clipboard()

# %%
stop

# %%
dist_df = pd.read_clipboard()

# %%
dist_df
# Out:
#             _id            US_Dist
# 0    tt10374610          Lionsgate
# 1    tt27847051               Neon
# 2    tt31888477     Focus Features
# 3    tt32992509  Star Invest Films
# 4    tt33837526                NaN
# ..          ...                ...
# 639         NaN                NaN
# 640         NaN                NaN
# 641         NaN                NaN
# 642         NaN                NaN
# 643         NaN                NaN
#
# [644 rows x 2 columns]

# %%
dist_df = dist_df.dropna(subset="US_Dist")

# %%
dist_df
# Out:
#             _id                              US_Dist
# 0    tt10374610                            Lionsgate
# 1    tt27847051                                 Neon
# 2    tt31888477                       Focus Features
# 3    tt32992509                    Star Invest Films
# 5    tt35500333            Sophie Dulac Distribution
# ..          ...                                  ...
# 485  tt32328541                         Warner Bros.
# 486  tt21361444  Walt Disney Studios Motion Pictures
# 487  tt33088418  Walt Disney Studios Motion Pictures
# 489   tt3095356                 20th Century Studios
# 490   tt5637536                 20th Century Studios
#
# [185 rows x 2 columns]

# %%
final_export = dist_df.to_dict(orient='records')

# %%
final_export
# Out:
# [{'_id': 'tt10374610', 'US_Dist': 'Lionsgate'},
#  {'_id': 'tt27847051', 'US_Dist': 'Neon'},
#  {'_id': 'tt31888477', 'US_Dist': 'Focus Features'},
#  {'_id': 'tt32992509', 'US_Dist': 'Star Invest Films'},
#  {'_id': 'tt35500333', 'US_Dist': 'Sophie Dulac Distribution'},
#  {'_id': 'tt23157384', 'US_Dist': 'UTA Independent Film Group'},
#  {'_id': 'tt33039440', 'US_Dist': 'Netflix'},
#  {'_id': 'tt35652650', 'US_Dist': 'Netflix'},
#  {'_id': 'tt15799524', 'US_Dist': 'MUBI'},
#  {'_id': 'tt1934397', 'US_Dist': 'Level 33 Entertainment'},
#  {'_id': 'tt20222166', 'US_Dist': 'Bleecker Street Media'},
#  {'_id': 'tt26394837', 'US_Dist': 'Aura Entertainment'},
#  {'_id': 'tt29567402', 'US_Dist': 'Magnolia Pictures'},
#  {'_id': 'tt31101921', 'US_Dist': 'Walt Disney Studios Motion Pictures'},
#  {'_id': 'tt31883677', 'US_Dist': 'Verve Pictures'},
#  {'_id': 'tt36607192', 'US_Dist': 'Toei Company'},
#  {'_id': 'tt29644189', 'US_Dist': 'Universal Pictures'},
# ...

# %%
from pymongo import UpdateOne

operations = [
    UpdateOne(
        {"_id": doc["_id"]},
        {"$set": doc},
        upsert=True
    ) for doc in final_export
]

result = collection.bulk_write(operations)
print(f"Matched: {result.matched_count}, Inserted: {result.upserted_count}, Modified: {result.modified_count}")
# Out:
# Matched: 185, Inserted: 0, Modified: 185
