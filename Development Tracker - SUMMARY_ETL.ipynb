# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel("development_tracker/APH Development Tracker - 12.05.25.xlsx", sheet_name='ALL SUMMARY')

# %%
df
# Out:
#                                        Annapurna Unnamed: 1 Unnamed: 2  \
# 0    Development Report by Project by Department        NaN        NaN
# 1                         As of December 5, 2025        NaN        NaN
# 2                                            NaN        NaN        NaN
# 3                                            NaN        NaN        NaN
# 4                                            NaN        NaN     Status
# ..                                           ...        ...        ...
# 138                                Total Theatre        NaN        NaN
# 139                                          NaN        NaN        NaN
# 140                                    All Depts        NaN        NaN
# 141                                          NaN                   NaN
# 142                                          NaN                   NaN
#
#               Unnamed: 3           Unnamed: 4           Unnamed: 5  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3      Inception To Date         Year To Date    Inception To Date
# 4    2023-12-31 00:00:00  2024-12-31 00:00:00  2024-12-31 00:00:00
# ..                   ...                  ...                  ...
# 138                    0                    0                    0
# 139                  NaN                  NaN                  NaN
# 140           5028531.94           4130666.79           8497754.13
# 141                  NaN                  NaN                  NaN
# 142                  NaN                  NaN                  NaN
#
#               Unnamed: 6           Unnamed: 7  Unnamed: 8      Unnamed: 9  \
# 0                    NaN                  NaN         NaN             NaN
# 1                    NaN                  NaN         NaN             NaN
# 2                    NaN                  NaN         NaN             NaN
# 3           Year To Date      ITD TOTAL SPEND         NaN             NaN
# 4    2025-12-05 00:00:00  2025-12-05 00:00:00     Q4 2025         Q1 2026
# ..                   ...                  ...         ...             ...
# 138              8593.17              8593.17         NaN             NaN
# 139                  NaN                  NaN         NaN             NaN
# 140           6648269.04          15146023.17  1118250.58  5137201.405333
# 141                  NaN                  NaN         NaN             NaN
# 142                  NaN                  NaN         NaN             NaN
#
#      ...   Unnamed: 14 Unnamed: 15 Unnamed: 16          Unnamed: 17  \
# 0    ...           NaN         NaN         NaN                  NaN
# 1    ...           NaN         NaN         NaN                  NaN
# 2    ...           NaN         NaN         NaN                  NaN
# 3    ...     Remaining         NaN         NaN    ITD w Commitments
# 4    ...           NaN         NaN       check  2025-12-31 00:00:00
# ..   ...           ...         ...         ...                  ...
# 138  ...        220000         NaN         NaN            448593.17
# 139  ...           NaN         NaN         NaN                  NaN
# 140  ...  16541233.432  1363088.75           0         33812145.152
# 141  ...           NaN         NaN         NaN                  NaN
# 142  ...           NaN         NaN         NaN                  NaN
#
#     Unnamed: 18         Unnamed: 19 Unnamed: 20 Unnamed: 21  Unnamed: 22  \
# 0           NaN                 NaN         NaN         NaN          NaN
# 1           NaN                 NaN         NaN         NaN          NaN
# 2           NaN                 NaN         NaN         NaN          NaN
# 3           NaN                 NaN         NaN         NaN          NaN
# 4           NaN  Changes from Prior         NaN     SUMMARY          NaN
# ..          ...                 ...         ...         ...          ...
# 138         NaN                 NaN         NaN         NaN          NaN
# 139         NaN                 NaN         NaN         NaN          NaN
# 140         NaN                 NaN         NaN         NaN          NaN
# 141         NaN                 NaN         NaN         NaN          NaN
# 142         NaN                 NaN         NaN         NaN          NaN
#
#     Unnamed: 23
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4    DATE ADDED
# ..          ...
# 138         NaN
# 139         NaN
# 140         NaN
# 141         NaN
# 142         NaN
#
# [143 rows x 24 columns]

# %%
col_names = df.iloc[3].dropna()
col_dates = df.iloc[4].dropna()

# %%
col_actuals = df.iloc[5].dropna()

# %%
col_filter = ['Unnamed: 1','Unnamed: 2'] + list(set(col_names.index.to_list() + col_actuals.index.to_list()))

# %% [raw]
# df.index[df['Annapurna'] == 'Total Film (Closed Deals)']

# %%
start_index = df.index[df['Annapurna'] == 'Film'][0]+1
stop_index = df.index[df['Annapurna'] == 'Total Film (Closed + Capitalized Deals)'][0]-1

# %%
start_index_consult = df.index[df['Annapurna'] == 'Total Film (Closed + Capitalized Deals)'][0]+2
stop_index_consult = df.index[df['Annapurna'] == 'Total Film (Closed + Capitalized + Expensed Deals)'][0]-1

# %%
start_index_pending = df.index[df['Annapurna'] == 'Total Film (Closed + Capitalized + Expensed Deals)'][0]+2
stop_index_pending = df.index[df['Annapurna'] == 'Total Film (Closed + Capitalized + Expensed Deals + Pending)'][0]-1

# %%
start_index_TV = df.index[df['Annapurna'] == 'TV'][0]+1
stop_index_TV = df.index[df['Annapurna'] == 'Total TV (Closed + Capitalized Deals)'][0]-1

# %%
start_index_consult_TV = df.index[df['Annapurna'] == 'Total TV (Closed + Capitalized Deals)'][0]+2
stop_index_consult_TV = df.index[df['Annapurna'] == 'Total TV (Closed + Capitalized + Expensed Deals)'][0]-1

# %%
start_index_pending_TV = df.index[df['Annapurna'] == 'Total TV (Closed + Capitalized + Expensed Deals)'][0]+2
stop_index_pending_TV = df.index[df['Annapurna'] == 'Total TV (Closed + Capitalized + Expensed Deals + Pending)'][0]-1

# %%
start_index_corporate = df.index[df['Annapurna'] == 'Corporate'][0]+1
stop_index_corporate = df.index[df['Annapurna'] == ' Total Corporate'][0]-1

# %%
start_index_ani_film = df.index[df['Annapurna'] == 'Animation (Film)'][0]+1
stop_index_ani_film = df.index[df['Annapurna'] == 'Total Animation (Film)'][0]-1

# %%
start_index_ani_tv = df.index[df['Annapurna'] == 'Animation (TV)'][0]+1
stop_index_ani_tv = df.index[df['Annapurna'] == 'Total Animation (TV)'][0]-1

# %%
start_index_theatre = df.index[df['Annapurna'] == 'Theatre'][0]+1
stop_index_theatre = df.index[df['Annapurna'] == 'Total Theatre'][0]-1

# %%
data = df[start_index:stop_index]
data['division'] = "Film"
data_pending = df[start_index_pending:stop_index_pending]
data_pending['division'] = "Film"

data_tv = df[start_index_TV:stop_index_TV]
data_tv['division'] = "TV"

data_pending_TV = df[start_index_pending_TV:stop_index_pending_TV]
data_pending_TV['division'] = "TV"

data_corp = df[start_index_corporate:stop_index_corporate]
data_corp['division'] = "corporate"

data_ani_film = df[start_index_ani_film:stop_index_ani_film]
data_ani_film['division'] = "Animation_Film"

data_ani_TV= df[start_index_ani_tv:stop_index_ani_tv]
data_ani_TV['division'] = "Animation_TV"

data_ani_Theatre= df[start_index_theatre:stop_index_theatre]
data_ani_Theatre['division'] = "Theatre"


data_film_consult= df[start_index_consult:stop_index_consult]
data_film_consult['division'] = "Film"

data_tv_consult = df[start_index_consult_TV:stop_index_consult_TV]
data_tv_consult['division'] = "TV"

# %%
data = data.reset_index()
data['_id'] = data['Unnamed: 1'] + "_" + data['division'].astype(str)#  + "_" + data['index'].astype(str)

data_pending = data_pending.reset_index()
data_pending['_id'] = data_pending['Unnamed: 1']+ "_" + data_pending['division'].astype(str)#   + "_" + data_pending['index'].astype(str)

data_tv = data_tv.reset_index()
data_tv['_id'] = data_tv['Unnamed: 1']+ "_" + data_tv['division'].astype(str)#   + "_" + data_tv['index'].astype(str)

data_pending_TV = data_pending_TV.reset_index()
data_pending_TV['_id'] = data_pending_TV['Unnamed: 1']+ "_" + data_pending_TV['division'].astype(str)#   + "_" + data_pending_TV['index'].astype(str)

data_corp = data_corp.reset_index()
data_corp['_id'] = data_corp['Unnamed: 1']+ "_" + data_corp['division'].astype(str)#   + "_" + data_corp['index'].astype(str)

data_ani_film = data_ani_film.reset_index()
data_ani_film['_id'] = data_ani_film['Unnamed: 1']+ "_" + data_ani_film['division'].astype(str)#   + "_" + data_ani_film['index'].astype(str)

data_ani_TV = data_ani_TV.reset_index()
data_ani_TV['_id'] = data_ani_TV['Unnamed: 1']+ "_" + data_ani_TV['division'].astype(str)#   + "_" + data_ani_TV['index'].astype(str)

data_ani_Theatre = data_ani_Theatre.reset_index()
data_ani_Theatre['_id'] = data_ani_Theatre['Unnamed: 1']+ "_" + data_ani_Theatre['division'].astype(str)#   + "_" + data_ani_Theatre['index'].astype(str)


data_film_consult = data_film_consult.reset_index()
data_film_consult['_id'] = data_film_consult['Unnamed: 1']+ "_" + data_film_consult['division'].astype(str)#   + "_" + data_ani_film['index'].astype(str)

data_tv_consult = data_tv_consult.reset_index()
data_tv_consult['_id'] = data_tv_consult['Unnamed: 1']+ "_" + data_tv_consult['division'].astype(str)#   + "_" + data_ani_film['index'].astype(str)

# %%
pd.set_option('display.max_columns', None)  # show all columns

data
# Out:
#     index Annapurna                                         Unnamed: 1  \
# 0       7       NaN                 Even the Losers/ Unt. Randy Lanier
# 1       8       NaN                        The Silent Patient - Plan B
# 2       9       NaN                                  Unt Nicole Taylor
# 3      10       NaN                                   American Spartan
# 4      11       NaN                                  Unt James Sweeney
# 5      12       NaN                               Cuban Missile Crisis
# 6      13       NaN  Unt Bennett Miller (fka Untitled Charlie Kaufm...
# 7      14       NaN                                        Five Hitmen
# 8      15       NaN                              Untitled Dolly Parton
# 9      16       NaN                                       Finding Gobi
# 10     17       NaN                                                Syd
# 11     18       NaN                                           Norco 80
# 12     19       NaN                           Twelve Minutes (Anim/TV)
# 13     20       NaN                                     American Jewel
# 14     21       NaN                  Untitled Lessovitz, Quesada, Zund
# 15     22       NaN                                               Chef
# 16     23       NaN                               The Lost Wild - Film
#
#              Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5 Unnamed: 6  \
# 0   closed deals/active        NaN        NaN           0  2089738.5
# 1   closed deals/active  621510.95  1175887.1  1797398.05   143372.5
# 2   closed deals/active          0       3395        3395   279562.5
# 3   closed deals/active        NaN        NaN           0          0
# 4   closed deals/active        NaN        NaN           0       9940
# 5   closed deals/active        NaN        NaN           0     187925
# 6   closed deals/active          0   463944.9    463944.9 -374781.25
# 7   closed deals/active          0    56192.5     56192.5  200065.23
# 8   closed deals/active          0          0           0       5300
# 9   closed deals/active          0    15462.5     15462.5      18130
# 10  closed deals/active          0          0           0     223650
# 11  closed deals/active          0          0           0          0
# 12  closed deals/active   97049.73   10502.54   107552.27      19.39
# 13  closed deals/active        NaN        NaN         NaN   32993.48
# 14  closed deals/active   80040.06          0    80040.06          0
# 15  closed deals/active          0       1885        1885       2420
# 16  closed deals/active        NaN        NaN           0       1100
#
#     Unnamed: 7  Unnamed: 8    Unnamed: 9   Unnamed: 10   Unnamed: 11  \
# 0    2089738.5           0       1513125        500000        500000
# 1   1940770.55    46593.75      46593.75             0             0
# 2     282957.5           0     327468.75        142500         30000
# 3            0      187125        187125        249500             0
# 4         9940  178733.625    178733.625     76600.125     76600.125
# 5       187925           0        126225         49900         49900
# 6     89163.65           0             0             0             0
# 7    256257.73    93868.75         37275         37275             0
# 8         5300           0        124750        124750        187125
# 9      33592.5           0        124250        124250         62125
# 10      223650           0         74550             0             0
# 11           0  167306.255         67500             0             0
# 12   107571.66           0  82833.333333  41416.666667  82833.333333
# 13    32993.48           0     101272.32             0             0
# 14    80040.06         NaN           NaN           NaN           NaN
# 15        4305           0   63332.95525             0             0
# 16        1100           0             0             0             0
#
#       Unnamed: 12 Unnamed: 13  Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0               0     1250000      3013125      750000           0
# 1               0           0      31062.5       62125           0
# 2               0           0    439968.75       60000           0
# 3               0           0       623750         NaN           0
# 4               0     48457.5     510667.5     48457.5           0
# 5               0      140000       226025      140000           0
# 6               0    454687.5     454687.5         NaN           0
# 7               0   102506.25    168418.75   102506.25           0
# 8               0           0       436625         NaN           0
# 9           62125           0       372750         NaN           0
# 10              0           0        74550         NaN           0
# 11              0           0   234806.255         NaN           0
# 12  103541.666667         NaN       310625         NaN           0
# 13              0         NaN    101272.32         NaN           0
# 14            NaN         NaN            0         NaN           0
# 15              0           0  63332.95525         NaN           0
# 16              0           0            0         NaN           0
#
#     Unnamed: 17  Unnamed: 18 Unnamed: 19  Unnamed: 20  \
# 0     5852863.5          NaN         NaN          NaN
# 1    2033958.05          NaN         NaN          NaN
# 2     782926.25          NaN         NaN          NaN
# 3        623750          NaN         NaN          NaN
# 4        569065          NaN         NaN          NaN
# 5        553950          NaN         NaN          NaN
# 6     543851.15          NaN         NaN          NaN
# 7     527182.73          NaN         NaN          NaN
# 8        441925          NaN         NaN          NaN
# 9      406342.5          NaN         NaN          NaN
# 10       298200          NaN         NaN          NaN
# 11   234806.255          NaN         NaN          NaN
# 12    418196.66          NaN         NaN          NaN
# 13     134265.8          NaN         NaN          NaN
# 14     80040.06          NaN         NaN          NaN
# 15  67637.95525          NaN         NaN          NaN
# 16         1100          NaN         NaN          NaN
#
#                                           Unnamed: 21  Unnamed: 22  \
# 0   script fee $4M; dev fee $1M; $30k option exten...          NaN
# 1   polish and optional polish $100K; reflects the...          NaN
# 2     script fee $600K + fringe; optional polish $60K          NaN
# 3                   $500K first draft + first rewrite          NaN
# 4     script fee $411K + fringe; optional polish $39K          NaN
# 5   option $40K; script $330K + fringe; $85K optio...          NaN
# 6   delivery of first draft $375K + fringe; $20K r...          NaN
# 7   option $10K; remaining script fee $195K + frin...          NaN
# 8    script fee $350K + fringe (pending writing deal)          NaN
# 9    script fee $300K + fringe (pending writing deal)          NaN
# 10                          script fee $300K + fringe          NaN
# 11  script $450K + fringe - will be split 50% with...          NaN
# 12                                   script fee $250K          NaN
# 13                  script rewrite $53K; EP deal $75K          NaN
# 14                                                NaN          NaN
# 15                      WGA scale + 15% $50K + fringe          NaN
# 16                                                NaN          NaN
#
#    Unnamed: 23 division                                                _id
# 0          NaN     Film            Even the Losers/ Unt. Randy Lanier_Film
# 1          NaN     Film                   The Silent Patient - Plan B_Film
# 2          NaN     Film                             Unt Nicole Taylor_Film
# 3          NaN     Film                              American Spartan_Film
# 4          NaN     Film                             Unt James Sweeney_Film
# 5          NaN     Film                          Cuban Missile Crisis_Film
# 6          NaN     Film  Unt Bennett Miller (fka Untitled Charlie Kaufm...
# 7          NaN     Film                                   Five Hitmen_Film
# 8          NaN     Film                         Untitled Dolly Parton_Film
# 9          NaN     Film                                  Finding Gobi_Film
# 10         NaN     Film                                           Syd_Film
# 11         NaN     Film                                      Norco 80_Film
# 12         NaN     Film                      Twelve Minutes (Anim/TV)_Film
# 13         NaN     Film                                American Jewel_Film
# 14         NaN     Film             Untitled Lessovitz, Quesada, Zund_Film
# 15         NaN     Film                                          Chef_Film
# 16         NaN     Film                          The Lost Wild - Film_Film

# %%
combined_data = pd.concat([data,data_pending,data_tv,data_pending_TV,data_corp,data_ani_film,data_ani_TV,data_ani_Theatre, data_film_consult, data_tv_consult])

# %%
combined_data['Unnamed: 1'].unique()
# Out:
# array(['Even the Losers/ Unt. Randy Lanier',
#        'The Silent Patient - Plan B', 'Unt Nicole Taylor',
#        'American Spartan', 'Unt James Sweeney', 'Cuban Missile Crisis',
#        'Unt Bennett Miller (fka Untitled Charlie Kaufman Project)',
#        'Five Hitmen', 'Untitled Dolly Parton', 'Finding Gobi', 'Syd',
#        'Norco 80', 'Twelve Minutes (Anim/TV)', 'American Jewel',
#        'Untitled Lessovitz, Quesada, Zund', 'Chef',
#        'The Lost Wild - Film', 'Eric Warren Singer', 'Grind',
#        'The Legend of Georgia McBride', 'Blankets', 'Belly of the Beast',
#        'The Visit', 'Women Clothed by the Sun', 'The New Man',
#        'Unt Mr. Beast Fiction Project', 'Monument Valley',
#        'Minds on Fire', 'Control', 'Who is Maud Dixon', 'The Original',
#        'Hot Kid', 'Planet of Exile', 'Call Me Dad', 'The Voyeur',
#        'Unt. Carlo Bernard/International Mercenaries', 'Operator',
#        'The Tour', 'The Chosen One', 'Identical', 'Seized',
#        'Made in Utah', 'Untitled Mallory Project', 'Strangers',
#        'Darkside of the Moon', 'Unt. Death Hoax', 'Alan Wake',
#        'Unt. Shi Yang', 'Unt. Equestrian Series', 'Heartstring',
#        'Nomad Summer', 'Unt. Sports Fan Show', 'Biggest Little Farm',
#        'Unt. Game Doc Series', 'Executive Protection',
#        'Unt. John Cho Jean Kyoung Frazier (if/come)',
#        'Limbo (TV/FILM tbd)', 'Inside', 'Exit Party', 'Shot to Nothing',
#        'Murderland', 'Cutter & Tats', 'Kill the Rabbit',
#        'The Drifting Classroom', 'Gravity Let Me Go',
#        "Dude Where's My Castle", 'Sia Martinez', 'Calliope',
#        'Grant & Sherman', 'England Expects (Film)', 'Mantooth',
#        'Stray - Animation', 'Moomins', 'Haiet', 'COMA', 'Antarctica',
#        'Hellraiser', 'Nimona', 'FOO (Animation)', "Let's Boogey",
#        'Some Assembly Required', 'The Trap', 'Nick Weidenfeld',
#        'Sapiens - Animation', 'Witchfeld', 'Living the Dream',
#        'NARPS (Non-Associated Regular People)', 'Outlets',
#        '20,000 Leagues Under the Sea', 'Donut County - Anim/TV',
#        'Center Stage', 'Her', 'Inter Alia (Broadway 2026)',
#        'Case of the Existence of God', 'Stephen Feder fee',
#        'Conner (Literary Research)'], dtype=object)

# %%
col_names = col_names.to_dict()
col_dates = col_dates.to_dict()
col_actuals = col_actuals.to_dict()

# %% [raw]
# col_names['Unnamed: 16'] = "Remaining - Optional"
# col_names['Unnamed: 15'] = "Remaining - Committed"

# %%
col_actuals
# Out:
# {'Unnamed: 3': 'Actual',
#  'Unnamed: 4': 'Actual',
#  'Unnamed: 5': 'Actual',
#  'Unnamed: 6': 'Actual',
#  'Unnamed: 7': 'Actual',
#  'Unnamed: 14': 'Committed ',
#  'Unnamed: 15': 'Optional',
#  'Unnamed: 17': 'Actual + Committed + Optional'}

# %%
col_dates
# Out:
# {'Unnamed: 2': 'Status',
#  'Unnamed: 3': datetime.datetime(2023, 12, 31, 0, 0),
#  'Unnamed: 4': datetime.datetime(2024, 12, 31, 0, 0),
#  'Unnamed: 5': datetime.datetime(2024, 12, 31, 0, 0),
#  'Unnamed: 6': datetime.datetime(2025, 12, 5, 0, 0),
#  'Unnamed: 7': datetime.datetime(2025, 12, 5, 0, 0),
#  'Unnamed: 8': 'Q4 2025',
#  'Unnamed: 9': 'Q1 2026',
#  'Unnamed: 10': 'Q2 2026',
#  'Unnamed: 11': 'Q3 2026',
#  'Unnamed: 12': 'Q4 2026',
#  'Unnamed: 13': 'post 2026',
#  'Unnamed: 16': 'check',
#  'Unnamed: 17': datetime.datetime(2025, 12, 31, 0, 0),
#  'Unnamed: 19': 'Changes from Prior',
#  'Unnamed: 21': 'SUMMARY',
#  'Unnamed: 23': 'DATE ADDED'}

# %%
column_dict = col_actuals
column_dict.update(col_dates)

# %%
common_keys = set(col_names) & set(col_dates) & set(col_actuals)
column_dict_2 = {
    k: f"{col_names.get(k, '')} | {col_dates.get(k, '').strftime("%Y")}"
    for k in common_keys
}

# %%
column_dict_2
# Out:
# {'Unnamed: 17': 'ITD w Commitments | 2025',
#  'Unnamed: 6': 'Year To Date | 2025',
#  'Unnamed: 4': 'Year To Date | 2024',
#  'Unnamed: 7': 'ITD TOTAL SPEND | 2025',
#  'Unnamed: 3': 'Inception To Date | 2023',
#  'Unnamed: 5': 'Inception To Date | 2024'}

# %%
column_dict.update(column_dict_2)

# %%
column_dict
# Out:
# {'Unnamed: 3': 'Inception To Date | 2023',
#  'Unnamed: 4': 'Year To Date | 2024',
#  'Unnamed: 5': 'Inception To Date | 2024',
#  'Unnamed: 6': 'Year To Date | 2025',
#  'Unnamed: 7': 'ITD TOTAL SPEND | 2025',
#  'Unnamed: 14': 'Committed ',
#  'Unnamed: 15': 'Optional',
#  'Unnamed: 17': 'ITD w Commitments | 2025',
#  'Unnamed: 2': 'Status',
#  'Unnamed: 8': 'Q4 2025',
#  'Unnamed: 9': 'Q1 2026',
#  'Unnamed: 10': 'Q2 2026',
#  'Unnamed: 11': 'Q3 2026',
#  'Unnamed: 12': 'Q4 2026',
#  'Unnamed: 13': 'post 2026',
#  'Unnamed: 16': 'check',
#  'Unnamed: 19': 'Changes from Prior',
#  'Unnamed: 21': 'SUMMARY',
#  'Unnamed: 23': 'DATE ADDED'}

# %%
combined_data.head()
# Out:
#    index Annapurna                          Unnamed: 1           Unnamed: 2  \
# 0      7       NaN  Even the Losers/ Unt. Randy Lanier  closed deals/active
# 1      8       NaN         The Silent Patient - Plan B  closed deals/active
# 2      9       NaN                   Unt Nicole Taylor  closed deals/active
# 3     10       NaN                    American Spartan  closed deals/active
# 4     11       NaN                   Unt James Sweeney  closed deals/active
#
#   Unnamed: 3 Unnamed: 4  Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0        NaN        NaN           0  2089738.5   2089738.5           0
# 1  621510.95  1175887.1  1797398.05   143372.5  1940770.55    46593.75
# 2          0       3395        3395   279562.5    282957.5           0
# 3        NaN        NaN           0          0           0      187125
# 4        NaN        NaN           0       9940        9940  178733.625
#
#    Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 0     1513125      500000      500000           0     1250000     3013125
# 1    46593.75           0           0           0           0     31062.5
# 2   327468.75      142500       30000           0           0   439968.75
# 3      187125      249500           0           0           0      623750
# 4  178733.625   76600.125   76600.125           0     48457.5    510667.5
#
#   Unnamed: 15 Unnamed: 16 Unnamed: 17  Unnamed: 18 Unnamed: 19  Unnamed: 20  \
# 0      750000           0   5852863.5          NaN         NaN          NaN
# 1       62125           0  2033958.05          NaN         NaN          NaN
# 2       60000           0   782926.25          NaN         NaN          NaN
# 3         NaN           0      623750          NaN         NaN          NaN
# 4     48457.5           0      569065          NaN         NaN          NaN
#
#                                          Unnamed: 21  Unnamed: 22 Unnamed: 23  \
# 0  script fee $4M; dev fee $1M; $30k option exten...          NaN         NaN
# 1  polish and optional polish $100K; reflects the...          NaN         NaN
# 2    script fee $600K + fringe; optional polish $60K          NaN         NaN
# 3                  $500K first draft + first rewrite          NaN         NaN
# 4    script fee $411K + fringe; optional polish $39K          NaN         NaN
#
#   division                                      _id
# 0     Film  Even the Losers/ Unt. Randy Lanier_Film
# 1     Film         The Silent Patient - Plan B_Film
# 2     Film                   Unt Nicole Taylor_Film
# 3     Film                    American Spartan_Film
# 4     Film                   Unt James Sweeney_Film

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
column_dict['Unnamed: 1'] = "Title"
#column_dict['Unnamed: 16'] = "Remaining - Optional"
#column_dict['Unnamed: 15'] = "Remaining - Committed"

# %%
combined_data = combined_data.rename(column_dict, axis=1)
#data = data.rename(col_names, axis=1)

# %%
clean_cols = [col for col in combined_data.columns if "unnamed" not in col.lower() and col != "Annapurna"]

# %%
final_data = combined_data[clean_cols]

# %%
final_data
# Out:
#     index                               Title               Status  \
# 0       7  Even the Losers/ Unt. Randy Lanier  closed deals/active
# 1       8         The Silent Patient - Plan B  closed deals/active
# 2       9                   Unt Nicole Taylor  closed deals/active
# 3      10                    American Spartan  closed deals/active
# 4      11                   Unt James Sweeney  closed deals/active
# ..    ...                                 ...                  ...
# 2     135          Inter Alia (Broadway 2026)              pending
# 3     136        Case of the Existence of God             inactive
# 0      27                   Stephen Feder fee  closed deals/active
# 1      28          Conner (Literary Research)  closed deals/active
# 0      72          Conner (Literary Research)  closed deals/active
#
#    Inception To Date | 2023 Year To Date | 2024 Inception To Date | 2024  \
# 0                       NaN                 NaN                        0
# 1                 621510.95           1175887.1               1797398.05
# 2                         0                3395                     3395
# 3                       NaN                 NaN                        0
# 4                       NaN                 NaN                        0
# ..                      ...                 ...                      ...
# 2                       NaN                 NaN                        0
# 3                         0                   0                        0
# 0                         0            176824.8                 176824.8
# 1                    153450               34800                   188250
# 0                    153450               34800                   188250
#
#    Year To Date | 2025 ITD TOTAL SPEND | 2025     Q4 2025     Q1 2026  \
# 0            2089738.5              2089738.5           0     1513125
# 1             143372.5             1940770.55    46593.75    46593.75
# 2             279562.5               282957.5           0   327468.75
# 3                    0                      0      187125      187125
# 4                 9940                   9940  178733.625  178733.625
# ..                 ...                    ...         ...         ...
# 2                  NaN                      0         NaN         NaN
# 3              8593.17                8593.17         NaN         NaN
# 0            391392.76              568217.56       35581       35581
# 1                31900                 220150        2900        8700
# 0                31900                 220150        2900        8700
#
#       Q2 2026    Q3 2026 Q4 2026 post 2026 Committed  Optional check  \
# 0      500000     500000       0   1250000    3013125   750000     0
# 1           0          0       0         0    31062.5    62125     0
# 2      142500      30000       0         0  439968.75    60000     0
# 3      249500          0       0         0     623750      NaN     0
# 4   76600.125  76600.125       0   48457.5   510667.5  48457.5     0
# ..        ...        ...     ...       ...        ...      ...   ...
# 2         NaN        NaN     NaN       NaN        NaN      NaN     0
# 3         NaN        NaN     NaN       NaN          0      NaN   NaN
# 0           0          0       0       NaN      71162      NaN     0
# 1        8700       8700    8700         0      37700      NaN     0
# 0        8700       8700    8700         0      37700      NaN     0
#
#    ITD w Commitments | 2025 Changes from Prior  \
# 0                 5852863.5                NaN
# 1                2033958.05                NaN
# 2                 782926.25                NaN
# 3                    623750                NaN
# 4                    569065                NaN
# ..                      ...                ...
# 2                         0                NaN
# 3                   8593.17                NaN
# 0                 639379.56                NaN
# 1                    257850                NaN
# 0                    257850                NaN
#
#                                               SUMMARY DATE ADDED division  \
# 0   script fee $4M; dev fee $1M; $30k option exten...        NaN     Film
# 1   polish and optional polish $100K; reflects the...        NaN     Film
# 2     script fee $600K + fringe; optional polish $60K        NaN     Film
# 3                   $500K first draft + first rewrite        NaN     Film
# 4     script fee $411K + fringe; optional polish $39K        NaN     Film
# ..                                                ...        ...      ...
# 2                                                 NaN        NaN  Theatre
# 3                                                 NaN        NaN  Theatre
# 0                               5 months of fee $178K        NaN     Film
# 1                                15 months @ $2.9K/mo        NaN     Film
# 0                                15 months @ $2.9K/mo        NaN       TV
#
#                                         _id
# 0   Even the Losers/ Unt. Randy Lanier_Film
# 1          The Silent Patient - Plan B_Film
# 2                    Unt Nicole Taylor_Film
# 3                     American Spartan_Film
# 4                    Unt James Sweeney_Film
# ..                                      ...
# 2        Inter Alia (Broadway 2026)_Theatre
# 3      Case of the Existence of God_Theatre
# 0                    Stephen Feder fee_Film
# 1           Conner (Literary Research)_Film
# 0             Conner (Literary Research)_TV
#
# [98 rows x 23 columns]

# %%
from datetime import datetime
final_data['update_date'] = datetime.today()

# %%
type_dict = {'Title':'string', 
             'Status':'string', 
             'Inception To Date | 2023':'float',
             'Year To Date | 2024':'float', 
             'Inception To Date | 2024':'float',
             'Year To Date | 2025':'float', 
             'ITD TOTAL SPEND | 2025':'float',
             'Committed ':'float', 
             'Optional':'float',
             'ITD w Commitments | 2025':'float', 
             'Changes from Prior':'string',
             'SUMMARY':'string'
            }

# %%
final_data = final_data.astype(type_dict)

# %%
final_data['Committed '].sum()/1_000_000
# Out:
# 16.541233432

# %%
final_data['ITD w Commitments | 2025'].sum()/1_000_000
# Out:
# 33.812145152

# %%
final_data['Optional'].sum()/1_000_000
# Out:
# 1.36308875

# %%
final_data['ITD TOTAL SPEND | 2025'].sum()/1_000_000
# Out:
# 15.146023170000001

# %%
final_data['Changes from Prior'] = final_data['Changes from Prior'].fillna("")
final_data['SUMMARY'] = final_data['SUMMARY'].fillna("")
final_data['Status'] = final_data['Status'].fillna("")

# %%
final_data.query("division =='Film'")
# Out:
#     index                                              Title  \
# 0       7                 Even the Losers/ Unt. Randy Lanier
# 1       8                        The Silent Patient - Plan B
# 2       9                                  Unt Nicole Taylor
# 3      10                                   American Spartan
# 4      11                                  Unt James Sweeney
# 5      12                               Cuban Missile Crisis
# 6      13  Unt Bennett Miller (fka Untitled Charlie Kaufm...
# 7      14                                        Five Hitmen
# 8      15                              Untitled Dolly Parton
# 9      16                                       Finding Gobi
# 10     17                                                Syd
# 11     18                                           Norco 80
# 12     19                           Twelve Minutes (Anim/TV)
# 13     20                                     American Jewel
# 14     21                  Untitled Lessovitz, Quesada, Zund
# 15     22                                               Chef
# 16     23                               The Lost Wild - Film
# 0      32                                 Eric Warren Singer
# 1      33                                              Grind
# 2      34                      The Legend of Georgia McBride
# 3      35                                           Blankets
# 4      36                                 Belly of the Beast
# 5      37                                          The Visit
# 6      38                           Women Clothed by the Sun
# 7      39                                        The New Man
# 8      40                      Unt Mr. Beast Fiction Project
# 9      41                                    Monument Valley
# 10     42                                      Minds on Fire
# 0      27                                  Stephen Feder fee
# 1      28                         Conner (Literary Research)
#
#                  Status  Inception To Date | 2023  Year To Date | 2024  \
# 0   closed deals/active                       NaN                  NaN
# 1   closed deals/active                 621510.95           1175887.10
# 2   closed deals/active                      0.00              3395.00
# 3   closed deals/active                       NaN                  NaN
# 4   closed deals/active                       NaN                  NaN
# 5   closed deals/active                       NaN                  NaN
# 6   closed deals/active                      0.00            463944.90
# 7   closed deals/active                      0.00             56192.50
# 8   closed deals/active                      0.00                 0.00
# 9   closed deals/active                      0.00             15462.50
# 10  closed deals/active                      0.00                 0.00
# 11  closed deals/active                      0.00                 0.00
# 12  closed deals/active                  97049.73             10502.54
# 13  closed deals/active                       NaN                  NaN
# 14  closed deals/active                  80040.06                 0.00
# 15  closed deals/active                      0.00              1885.00
# 16  closed deals/active                       NaN                  NaN
# 0               pending                       NaN                  NaN
# 1               pending                       NaN                  NaN
# 2               pending                      0.00                 0.00
# 3               pending                       NaN                  NaN
# 4               pending                       NaN                  NaN
# 5               pending                      0.00                 0.00
# 6               pending                       NaN                  NaN
# 7               pending                      0.00              1522.50
# 8               pending                       NaN                  NaN
# 9               pending                       NaN                  NaN
# 10              pending                       NaN                  NaN
# 0   closed deals/active                      0.00            176824.80
# 1   closed deals/active                 153450.00             34800.00
#
#     Inception To Date | 2024  Year To Date | 2025  ITD TOTAL SPEND | 2025  \
# 0                       0.00           2089738.50              2089738.50
# 1                 1797398.05            143372.50              1940770.55
# 2                    3395.00            279562.50               282957.50
# 3                       0.00                 0.00                    0.00
# 4                       0.00              9940.00                 9940.00
# 5                       0.00            187925.00               187925.00
# 6                  463944.90           -374781.25                89163.65
# 7                   56192.50            200065.23               256257.73
# 8                       0.00              5300.00                 5300.00
# 9                   15462.50             18130.00                33592.50
# 10                      0.00            223650.00               223650.00
# 11                      0.00                 0.00                    0.00
# 12                 107552.27                19.39               107571.66
# 13                       NaN             32993.48                32993.48
# 14                  80040.06                 0.00                80040.06
# 15                   1885.00              2420.00                 4305.00
# 16                      0.00              1100.00                 1100.00
# 0                       0.00                 0.00                    0.00
# 1                       0.00                 0.00                    0.00
# 2                       0.00                 0.00                    0.00
# 3                        NaN                  NaN                     NaN
# 4                       0.00             55104.86                55104.86
# 5                       0.00               268.17                  268.17
# 6                       0.00             30638.73                30638.73
# 7                    1522.50                 0.00                 1522.50
# 8                       0.00                 0.00                    0.00
# 9                        NaN                  NaN                    0.00
# 10                       NaN                  NaN                    0.00
# 0                  176824.80            391392.76               568217.56
# 1                  188250.00             31900.00               220150.00
#
#        Q4 2025       Q1 2026       Q2 2026       Q3 2026        Q4 2026  \
# 0            0       1513125        500000        500000              0
# 1     46593.75      46593.75             0             0              0
# 2            0     327468.75        142500         30000              0
# 3       187125        187125        249500             0              0
# 4   178733.625    178733.625     76600.125     76600.125              0
# 5            0        126225         49900         49900              0
# 6            0             0             0             0              0
# 7     93868.75         37275         37275             0              0
# 8            0        124750        124750        187125              0
# 9            0        124250        124250         62125          62125
# 10           0         74550             0             0              0
# 11  167306.255         67500             0             0              0
# 12           0  82833.333333  41416.666667  82833.333333  103541.666667
# 13           0     101272.32             0             0              0
# 14         NaN           NaN           NaN           NaN            NaN
# 15           0   63332.95525             0             0              0
# 16           0             0             0             0              0
# 0          NaN           NaN       4500000           NaN            NaN
# 1       202275        202275        134850        134850              0
# 2            0             0         62375         62375          62375
# 3          NaN         10000         75000         62500          62500
# 4            0     139233.38             0             0              0
# 5            0         52000             0             0              0
# 6          NaN           NaN           NaN           NaN            NaN
# 7          NaN           NaN           NaN           NaN            NaN
# 8          NaN           NaN           NaN           NaN            NaN
# 9          NaN           NaN           NaN           NaN            NaN
# 10         NaN           NaN           NaN           NaN            NaN
# 0        35581         35581             0             0              0
# 1         2900          8700          8700          8700           8700
#
#     post 2026    Committed    Optional check  ITD w Commitments | 2025  \
# 0     1250000  3.013125e+06  750000.00     0              5.852864e+06
# 1           0  3.106250e+04   62125.00     0              2.033958e+06
# 2           0  4.399688e+05   60000.00     0              7.829262e+05
# 3           0  6.237500e+05        NaN     0              6.237500e+05
# 4     48457.5  5.106675e+05   48457.50     0              5.690650e+05
# 5      140000  2.260250e+05  140000.00     0              5.539500e+05
# 6    454687.5  4.546875e+05        NaN     0              5.438512e+05
# 7   102506.25  1.684188e+05  102506.25     0              5.271827e+05
# 8           0  4.366250e+05        NaN     0              4.419250e+05
# 9           0  3.727500e+05        NaN     0              4.063425e+05
# 10          0  7.455000e+04        NaN     0              2.982000e+05
# 11          0  2.348063e+05        NaN     0              2.348063e+05
# 12        NaN  3.106250e+05        NaN     0              4.181967e+05
# 13        NaN  1.012723e+05        NaN     0              1.342658e+05
# 14        NaN  0.000000e+00        NaN     0              8.004006e+04
# 15          0  6.333296e+04        NaN     0              6.763796e+04
# 16          0  0.000000e+00        NaN     0              1.100000e+03
# 0         NaN  4.500000e+06        NaN     0              4.500000e+06
# 1           0  6.742500e+05        NaN     0              6.742500e+05
# 2       62375  2.495000e+05        NaN     0              2.495000e+05
# 3         NaN  2.100000e+05        NaN     0              2.100000e+05
# 4           0  6.423338e+04   75000.00     0              1.943382e+05
# 5           0  5.200000e+04        NaN     0              5.226817e+04
# 6         NaN           NaN        NaN     0              3.063873e+04
# 7         NaN  0.000000e+00        NaN     0              1.522500e+03
# 8         NaN  0.000000e+00        NaN     0              0.000000e+00
# 9         NaN           NaN        NaN     0              0.000000e+00
# 10        NaN           NaN        NaN   NaN              0.000000e+00
# 0         NaN  7.116200e+04        NaN     0              6.393796e+05
# 1           0  3.770000e+04        NaN     0              2.578500e+05
#
#    Changes from Prior                                            SUMMARY  \
# 0                      script fee $4M; dev fee $1M; $30k option exten...
# 1                      polish and optional polish $100K; reflects the...
# 2                        script fee $600K + fringe; optional polish $60K
# 3                                      $500K first draft + first rewrite
# 4                        script fee $411K + fringe; optional polish $39K
# 5                      option $40K; script $330K + fringe; $85K optio...
# 6                      delivery of first draft $375K + fringe; $20K r...
# 7                      option $10K; remaining script fee $195K + frin...
# 8                       script fee $350K + fringe (pending writing deal)
# 9                       script fee $300K + fringe (pending writing deal)
# 10                                             script fee $300K + fringe
# 11                     script $450K + fringe - will be split 50% with...
# 12                                                      script fee $250K
# 13                                     script rewrite $53K; EP deal $75K
# 14
# 15                                         WGA scale + 15% $50K + fringe
# 16
# 0                                                      script deal $4.5M
# 1                                              script fee $600K + fringe
# 2                                              script fee $200K + fringe
# 3                                       script fee $200K and option $10K
# 4                      option fee 37K; optional polish 75K, 32K budge...
# 5                                                option $50K; $2K travel
# 6
# 7
# 8
# 9
# 10
# 0                                                  5 months of fee $178K
# 1                                                   15 months @ $2.9K/mo
#
#              DATE ADDED division  \
# 0                   NaN     Film
# 1                   NaN     Film
# 2                   NaN     Film
# 3                   NaN     Film
# 4                   NaN     Film
# 5                   NaN     Film
# 6                   NaN     Film
# 7                   NaN     Film
# 8                   NaN     Film
# 9                   NaN     Film
# 10                  NaN     Film
# 11                  NaN     Film
# 12                  NaN     Film
# 13                  NaN     Film
# 14                  NaN     Film
# 15                  NaN     Film
# 16                  NaN     Film
# 0                   NaN     Film
# 1                   NaN     Film
# 2                   NaN     Film
# 3                   NaN     Film
# 4                   NaN     Film
# 5                   NaN     Film
# 6                   NaN     Film
# 7                   NaN     Film
# 8                   NaN     Film
# 9                   NaN     Film
# 10  2025-10-14 00:00:00     Film
# 0                   NaN     Film
# 1                   NaN     Film
#
#                                                   _id  \
# 0             Even the Losers/ Unt. Randy Lanier_Film
# 1                    The Silent Patient - Plan B_Film
# 2                              Unt Nicole Taylor_Film
# 3                               American Spartan_Film
# 4                              Unt James Sweeney_Film
# 5                           Cuban Missile Crisis_Film
# 6   Unt Bennett Miller (fka Untitled Charlie Kaufm...
# 7                                    Five Hitmen_Film
# 8                          Untitled Dolly Parton_Film
# 9                                   Finding Gobi_Film
# 10                                           Syd_Film
# 11                                      Norco 80_Film
# 12                      Twelve Minutes (Anim/TV)_Film
# 13                                American Jewel_Film
# 14             Untitled Lessovitz, Quesada, Zund_Film
# 15                                          Chef_Film
# 16                          The Lost Wild - Film_Film
# 0                             Eric Warren Singer_Film
# 1                                          Grind_Film
# 2                  The Legend of Georgia McBride_Film
# 3                                       Blankets_Film
# 4                             Belly of the Beast_Film
# 5                                      The Visit_Film
# 6                       Women Clothed by the Sun_Film
# 7                                    The New Man_Film
# 8                  Unt Mr. Beast Fiction Project_Film
# 9                                Monument Valley_Film
# 10                                 Minds on Fire_Film
# 0                              Stephen Feder fee_Film
# 1                     Conner (Literary Research)_Film
#
#                   update_date
# 0  2025-12-10 06:09:21.519864
# 1  2025-12-10 06:09:21.519864
# 2  2025-12-10 06:09:21.519864
# 3  2025-12-10 06:09:21.519864
# 4  2025-12-10 06:09:21.519864
# 5  2025-12-10 06:09:21.519864
# 6  2025-12-10 06:09:21.519864
# 7  2025-12-10 06:09:21.519864
# 8  2025-12-10 06:09:21.519864
# 9  2025-12-10 06:09:21.519864
# 10 2025-12-10 06:09:21.519864
# 11 2025-12-10 06:09:21.519864
# 12 2025-12-10 06:09:21.519864
# 13 2025-12-10 06:09:21.519864
# 14 2025-12-10 06:09:21.519864
# 15 2025-12-10 06:09:21.519864
# 16 2025-12-10 06:09:21.519864
# 0  2025-12-10 06:09:21.519864
# 1  2025-12-10 06:09:21.519864
# 2  2025-12-10 06:09:21.519864
# 3  2025-12-10 06:09:21.519864
# 4  2025-12-10 06:09:21.519864
# 5  2025-12-10 06:09:21.519864
# 6  2025-12-10 06:09:21.519864
# 7  2025-12-10 06:09:21.519864
# 8  2025-12-10 06:09:21.519864
# 9  2025-12-10 06:09:21.519864
# 10 2025-12-10 06:09:21.519864
# 0  2025-12-10 06:09:21.519864
# 1  2025-12-10 06:09:21.519864

# %%
from datetime import datetime

doc_list = []

for _, row in final_data.iterrows():
    #changes_val = row['changes']
    #changes_val = str(changes_val) if pd.notna(changes_val) else ""

    new_update = {
        'update_date': row['update_date'],
        'Status': row['Status'],
        'title': row['Title'],
        'ITD_2023': row['Inception To Date | 2023'],
        'ITD_2024': row['Inception To Date | 2024'],
        'ITD_2025': row['ITD TOTAL SPEND | 2025'],
        '2024_spend': row['Year To Date | 2024'],
        '2025_spend': row['Year To Date | 2025'],
        'Remaining_Committed': row['Committed '],
        'Remaining_Optional': row['Optional'],
        'Total_Cost_with_Committments': row['ITD w Commitments | 2025'],
        'Changes':row['Changes from Prior'],
        "Summary":row['SUMMARY']
    }

    doc = {
        '_id': row['_id'],
        #'date_added':row['DATE ADDED'],
        'title': row['Title'],
        'division': row['division'].lower(),
        'Status': row['Status'],
        'update_date': row['update_date'],
        'Total_Cost_with_Committments': new_update['Total_Cost_with_Committments'],
        'ITD_2025': new_update['ITD_2025'],
        'Remaining_Committed': new_update['Remaining_Committed'],
        'Remaining_Optional': new_update['Remaining_Optional'],
        'Changes': new_update['Changes'],
        # This will *append* to the history on upsert
        '$push': {'updates': new_update}
    }

    doc_list.append(doc)

# %%
## Establish connection to Account
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://dougsack:Ocana2421@cluster1.zdl0b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster1"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db = client['InDevelopment']

collection = db['development_tracker']

# %%
len(doc_list)
# Out:
# 98

# %%
doc_list
# Out:
# [{'_id': 'Even the Losers/ Unt. Randy Lanier_Film',
#   'title': 'Even the Losers/ Unt. Randy Lanier',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 5852863.5,
#   'ITD_2025': 2089738.5,
#   'Remaining_Committed': 3013125.0,
#   'Remaining_Optional': 750000.0,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Even the Losers/ Unt. Randy Lanier',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 2089738.5,
#     '2024_spend': nan,
#     '2025_spend': 2089738.5,
#     'Remaining_Committed': 3013125.0,
#     'Remaining_Optional': 750000.0,
#     'Total_Cost_with_Committments': 5852863.5,
#     'Changes': '',
#     'Summary': 'script fee $4M; dev fee $1M; $30k option extension; $13K consulting fee; $750K optional rewrite and polish'}}},
#  {'_id': 'The Silent Patient - Plan B_Film',
#   'title': 'The Silent Patient - Plan B',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 2033958.05,
#   'ITD_2025': 1940770.55,
#   'Remaining_Committed': 31062.5,
#   'Remaining_Optional': 62125.0,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'The Silent Patient - Plan B',
#     'ITD_2023': 621510.95,
#     'ITD_2024': 1797398.05,
#     'ITD_2025': 1940770.55,
#     '2024_spend': 1175887.1,
#     '2025_spend': 143372.5,
#     'Remaining_Committed': 31062.5,
#     'Remaining_Optional': 62125.0,
#     'Total_Cost_with_Committments': 2033958.05,
#     'Changes': '',
#     'Summary': 'polish and optional polish $100K; reflects the $925K option purchase'}}},
#  {'_id': 'Unt Nicole Taylor_Film',
#   'title': 'Unt Nicole Taylor',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 782926.25,
#   'ITD_2025': 282957.5,
#   'Remaining_Committed': 439968.75,
#   'Remaining_Optional': 60000.0,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Unt Nicole Taylor',
#     'ITD_2023': 0.0,
#     'ITD_2024': 3395.0,
#     'ITD_2025': 282957.5,
#     '2024_spend': 3395.0,
#     '2025_spend': 279562.5,
#     'Remaining_Committed': 439968.75,
#     'Remaining_Optional': 60000.0,
#     'Total_Cost_with_Committments': 782926.25,
#     'Changes': '',
#     'Summary': 'script fee $600K + fringe; optional polish $60K'}}},
#  {'_id': 'American Spartan_Film',
#   'title': 'American Spartan',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 623750.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 623750.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'American Spartan',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 623750.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 623750.0,
#     'Changes': '',
#     'Summary': '$500K first draft + first rewrite'}}},
#  {'_id': 'Unt James Sweeney_Film',
#   'title': 'Unt James Sweeney',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 569065.0,
#   'ITD_2025': 9940.0,
#   'Remaining_Committed': 510667.5,
#   'Remaining_Optional': 48457.5,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Unt James Sweeney',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 9940.0,
#     '2024_spend': nan,
#     '2025_spend': 9940.0,
#     'Remaining_Committed': 510667.5,
#     'Remaining_Optional': 48457.5,
#     'Total_Cost_with_Committments': 569065.0,
#     'Changes': '',
#     'Summary': 'script fee $411K + fringe; optional polish $39K'}}},
#  {'_id': 'Cuban Missile Crisis_Film',
#   'title': 'Cuban Missile Crisis',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 553950.0,
#   'ITD_2025': 187925.0,
#   'Remaining_Committed': 226025.0,
#   'Remaining_Optional': 140000.0,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Cuban Missile Crisis',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 187925.0,
#     '2024_spend': nan,
#     '2025_spend': 187925.0,
#     'Remaining_Committed': 226025.0,
#     'Remaining_Optional': 140000.0,
#     'Total_Cost_with_Committments': 553950.0,
#     'Changes': '',
#     'Summary': 'option $40K; script $330K + fringe; $85K optional rewrite; $55K optional polish'}}},
#  {'_id': 'Unt Bennett Miller (fka Untitled Charlie Kaufman Project)_Film',
#   'title': 'Unt Bennett Miller (fka Untitled Charlie Kaufman Project)',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 543851.15,
#   'ITD_2025': 89163.65000000002,
#   'Remaining_Committed': 454687.5,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Unt Bennett Miller (fka Untitled Charlie Kaufman Project)',
#     'ITD_2023': 0.0,
#     'ITD_2024': 463944.9,
#     'ITD_2025': 89163.65000000002,
#     '2024_spend': 463944.9,
#     '2025_spend': -374781.25,
#     'Remaining_Committed': 454687.5,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 543851.15,
#     'Changes': '',
#     'Summary': 'delivery of first draft $375K + fringe; $20K research (pending writing deal) '}}},
#  {'_id': 'Five Hitmen_Film',
#   'title': 'Five Hitmen',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 527182.73,
#   'ITD_2025': 256257.72999999998,
#   'Remaining_Committed': 168418.75,
#   'Remaining_Optional': 102506.25,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Five Hitmen',
#     'ITD_2023': 0.0,
#     'ITD_2024': 56192.5,
#     'ITD_2025': 256257.72999999998,
#     '2024_spend': 56192.5,
#     '2025_spend': 200065.22999999998,
#     'Remaining_Committed': 168418.75,
#     'Remaining_Optional': 102506.25,
#     'Total_Cost_with_Committments': 527182.73,
#     'Changes': '',
#     'Summary': 'option $10K; remaining script fee $195K + fringe; optional rewrite and polish $82.5K'}}},
#  {'_id': 'Untitled Dolly Parton_Film',
#   'title': 'Untitled Dolly Parton',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 441925.0,
#   'ITD_2025': 5300.0,
#   'Remaining_Committed': 436625.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Untitled Dolly Parton',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 5300.0,
#     '2024_spend': 0.0,
#     '2025_spend': 5300.0,
#     'Remaining_Committed': 436625.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 441925.0,
#     'Changes': '',
#     'Summary': 'script fee $350K + fringe (pending writing deal)'}}},
#  {'_id': 'Finding Gobi_Film',
#   'title': 'Finding Gobi',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 406342.5,
#   'ITD_2025': 33592.5,
#   'Remaining_Committed': 372750.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Finding Gobi',
#     'ITD_2023': 0.0,
#     'ITD_2024': 15462.5,
#     'ITD_2025': 33592.5,
#     '2024_spend': 15462.5,
#     '2025_spend': 18130.0,
#     'Remaining_Committed': 372750.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 406342.5,
#     'Changes': '',
#     'Summary': 'script fee $300K + fringe (pending writing deal)'}}},
#  {'_id': 'Syd_Film',
#   'title': 'Syd',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 298200.0,
#   'ITD_2025': 223650.0,
#   'Remaining_Committed': 74550.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Syd',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 223650.0,
#     '2024_spend': 0.0,
#     '2025_spend': 223650.0,
#     'Remaining_Committed': 74550.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 298200.0,
#     'Changes': '',
#     'Summary': 'script fee $300K + fringe'}}},
#  {'_id': 'Norco 80_Film',
#   'title': 'Norco 80',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 234806.255,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 234806.255,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Norco 80',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 234806.255,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 234806.255,
#     'Changes': '',
#     'Summary': 'script $450K + fringe - will be split 50% with Fifth Season'}}},
#  {'_id': 'Twelve Minutes (Anim/TV)_Film',
#   'title': 'Twelve Minutes (Anim/TV)',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 418196.66,
#   'ITD_2025': 107571.65999999999,
#   'Remaining_Committed': 310625.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Twelve Minutes (Anim/TV)',
#     'ITD_2023': 97049.73,
#     'ITD_2024': 107552.26999999999,
#     'ITD_2025': 107571.65999999999,
#     '2024_spend': 10502.54,
#     '2025_spend': 19.39,
#     'Remaining_Committed': 310625.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 418196.66,
#     'Changes': '',
#     'Summary': 'script fee $250K'}}},
#  {'_id': 'American Jewel_Film',
#   'title': 'American Jewel',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 134265.80000000002,
#   'ITD_2025': 32993.48,
#   'Remaining_Committed': 101272.32,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'American Jewel',
#     'ITD_2023': nan,
#     'ITD_2024': nan,
#     'ITD_2025': 32993.48,
#     '2024_spend': nan,
#     '2025_spend': 32993.48,
#     'Remaining_Committed': 101272.32,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 134265.80000000002,
#     'Changes': '',
#     'Summary': 'script rewrite $53K; EP deal $75K'}}},
#  {'_id': 'Untitled Lessovitz, Quesada, Zund_Film',
#   'title': 'Untitled Lessovitz, Quesada, Zund',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 80040.06,
#   'ITD_2025': 80040.06,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Untitled Lessovitz, Quesada, Zund',
#     'ITD_2023': 80040.06,
#     'ITD_2024': 80040.06,
#     'ITD_2025': 80040.06,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 80040.06,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Chef_Film',
#   'title': 'Chef',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 67637.95525,
#   'ITD_2025': 4305.0,
#   'Remaining_Committed': 63332.95524999999,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Chef',
#     'ITD_2023': 0.0,
#     'ITD_2024': 1885.0,
#     'ITD_2025': 4305.0,
#     '2024_spend': 1885.0,
#     '2025_spend': 2420.0,
#     'Remaining_Committed': 63332.95524999999,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 67637.95525,
#     'Changes': '',
#     'Summary': 'WGA scale + 15% $50K + fringe'}}},
#  {'_id': 'The Lost Wild - Film_Film',
#   'title': 'The Lost Wild - Film',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 1100.0,
#   'ITD_2025': 1100.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'The Lost Wild - Film',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 1100.0,
#     '2024_spend': nan,
#     '2025_spend': 1100.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 1100.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Eric Warren Singer_Film',
#   'title': 'Eric Warren Singer',
#   'division': 'film',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 4500000.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 4500000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Eric Warren Singer',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 4500000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 4500000.0,
#     'Changes': '',
#     'Summary': 'script deal $4.5M'}}},
#  {'_id': 'Grind_Film',
#   'title': 'Grind',
#   'division': 'film',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 674250.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 674250.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Grind',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 674250.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 674250.0,
#     'Changes': '',
#     'Summary': 'script fee $600K + fringe'}}},
#  {'_id': 'The Legend of Georgia McBride_Film',
#   'title': 'The Legend of Georgia McBride',
#   'division': 'film',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 249500.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 249500.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'The Legend of Georgia McBride',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 249500.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 249500.0,
#     'Changes': '',
#     'Summary': 'script fee $200K + fringe'}}},
#  {'_id': 'Blankets_Film',
#   'title': 'Blankets',
#   'division': 'film',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 210000.0,
#   'ITD_2025': nan,
#   'Remaining_Committed': 210000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Blankets',
#     'ITD_2023': nan,
#     'ITD_2024': nan,
#     'ITD_2025': nan,
#     '2024_spend': nan,
#     '2025_spend': nan,
#     'Remaining_Committed': 210000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 210000.0,
#     'Changes': '',
#     'Summary': 'script fee $200K and option $10K'}}},
#  {'_id': 'Belly of the Beast_Film',
#   'title': 'Belly of the Beast',
#   'division': 'film',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 194338.24,
#   'ITD_2025': 55104.86,
#   'Remaining_Committed': 64233.380000000005,
#   'Remaining_Optional': 75000.0,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Belly of the Beast',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 55104.86,
#     '2024_spend': nan,
#     '2025_spend': 55104.86,
#     'Remaining_Committed': 64233.380000000005,
#     'Remaining_Optional': 75000.0,
#     'Total_Cost_with_Committments': 194338.24,
#     'Changes': '',
#     'Summary': 'option fee 37K; optional polish 75K, 32K budgeting and scouting'}}},
#  {'_id': 'The Visit_Film',
#   'title': 'The Visit',
#   'division': 'film',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 52268.17,
#   'ITD_2025': 268.17,
#   'Remaining_Committed': 52000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'The Visit',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 268.17,
#     '2024_spend': 0.0,
#     '2025_spend': 268.17,
#     'Remaining_Committed': 52000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 52268.17,
#     'Changes': '',
#     'Summary': 'option $50K; $2K travel'}}},
#  {'_id': 'Women Clothed by the Sun_Film',
#   'title': 'Women Clothed by the Sun',
#   'division': 'film',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 30638.73,
#   'ITD_2025': 30638.73,
#   'Remaining_Committed': nan,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Women Clothed by the Sun',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 30638.73,
#     '2024_spend': nan,
#     '2025_spend': 30638.73,
#     'Remaining_Committed': nan,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 30638.73,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'The New Man_Film',
#   'title': 'The New Man',
#   'division': 'film',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 1522.5,
#   'ITD_2025': 1522.5,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'The New Man',
#     'ITD_2023': 0.0,
#     'ITD_2024': 1522.5,
#     'ITD_2025': 1522.5,
#     '2024_spend': 1522.5,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 1522.5,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Unt Mr. Beast Fiction Project_Film',
#   'title': 'Unt Mr. Beast Fiction Project',
#   'division': 'film',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Unt Mr. Beast Fiction Project',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Monument Valley_Film',
#   'title': 'Monument Valley',
#   'division': 'film',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': nan,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Monument Valley',
#     'ITD_2023': nan,
#     'ITD_2024': nan,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': nan,
#     'Remaining_Committed': nan,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Minds on Fire_Film',
#   'title': 'Minds on Fire',
#   'division': 'film',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': nan,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Minds on Fire',
#     'ITD_2023': nan,
#     'ITD_2024': nan,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': nan,
#     'Remaining_Committed': nan,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Control_TV',
#   'title': 'Control',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 763465.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 763465.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Control',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 763465.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 763465.0,
#     'Changes': '',
#     'Summary': 'script fee $633K + fringe'}}},
#  {'_id': 'Who is Maud Dixon_TV',
#   'title': 'Who is Maud Dixon',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 664050.7,
#   'ITD_2025': 539050.7,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': 125000.0,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Who is Maud Dixon',
#     'ITD_2023': 0.0,
#     'ITD_2024': 496303.31,
#     'ITD_2025': 539050.7,
#     '2024_spend': 496303.31,
#     '2025_spend': 42747.39,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': 125000.0,
#     'Total_Cost_with_Committments': 664050.7,
#     'Changes': '',
#     'Summary': 'option extension $125K optional'}}},
#  {'_id': 'The Original_TV',
#   'title': 'The Original',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 415398.73000000004,
#   'ITD_2025': 415398.73000000004,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'The Original',
#     'ITD_2023': 413488.75,
#     'ITD_2024': 415033.34,
#     'ITD_2025': 415398.73000000004,
#     '2024_spend': 1544.5900000000001,
#     '2025_spend': 365.39,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 415398.73000000004,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Hot Kid_TV',
#   'title': 'Hot Kid',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 408947.82,
#   'ITD_2025': 377885.32,
#   'Remaining_Committed': 31062.5,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Hot Kid',
#     'ITD_2023': 204995.27,
#     'ITD_2024': 266854.76,
#     'ITD_2025': 377885.32,
#     '2024_spend': 61859.49,
#     '2025_spend': 111030.56,
#     'Remaining_Committed': 31062.5,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 408947.82,
#     'Changes': '',
#     'Summary': 'polish $25K + fringe'}}},
#  {'_id': 'Planet of Exile_TV',
#   'title': 'Planet of Exile',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 383437.13,
#   'ITD_2025': 383437.13,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Planet of Exile',
#     'ITD_2023': 27147.030000000057,
#     'ITD_2024': 107724.27000000005,
#     'ITD_2025': 383437.13,
#     '2024_spend': 80577.23999999999,
#     '2025_spend': 275712.86,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 383437.13,
#     'Changes': '',
#     'Summary': 'artwork $10K'}}},
#  {'_id': 'Call Me Dad_TV',
#   'title': 'Call Me Dad',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 363801.82,
#   'ITD_2025': 313801.82,
#   'Remaining_Committed': 50000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Call Me Dad',
#     'ITD_2023': 0.0,
#     'ITD_2024': 238726.67,
#     'ITD_2025': 313801.82,
#     '2024_spend': 238726.67,
#     '2025_spend': 75075.15,
#     'Remaining_Committed': 50000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 363801.82,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'The Voyeur_TV',
#   'title': 'The Voyeur',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 217437.5,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 217437.5,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'The Voyeur',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 217437.5,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 217437.5,
#     'Changes': '',
#     'Summary': 'script fee split with fifth season $175K + fringe'}}},
#  {'_id': 'Unt. Carlo Bernard/International Mercenaries_TV',
#   'title': 'Unt. Carlo Bernard/International Mercenaries',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 154062.5,
#   'ITD_2025': 154062.5,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Unt. Carlo Bernard/International Mercenaries',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 154062.5,
#     '2024_spend': nan,
#     '2025_spend': 154062.5,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 154062.5,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Operator_TV',
#   'title': 'Operator',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 134178.31425,
#   'ITD_2025': 112031.42,
#   'Remaining_Committed': 22146.894249999998,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Operator',
#     'ITD_2023': 0.0,
#     'ITD_2024': 45000.0,
#     'ITD_2025': 112031.42,
#     '2024_spend': 45000.0,
#     '2025_spend': 67031.42,
#     'Remaining_Committed': 22146.894249999998,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 134178.31425,
#     'Changes': '',
#     'Summary': 'option $12.5K; format fee $25K'}}},
#  {'_id': 'The Tour_TV',
#   'title': 'The Tour',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 128031.0,
#   'ITD_2025': 123031.0,
#   'Remaining_Committed': 5000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'The Tour',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 123031.0,
#     '2024_spend': 0.0,
#     '2025_spend': 123031.0,
#     'Remaining_Committed': 5000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 128031.0,
#     'Changes': '',
#     'Summary': 'remaining script fee $50K + fringe; $5K travel'}}},
#  {'_id': 'The Chosen One_TV',
#   'title': 'The Chosen One',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 111769.27000000002,
#   'ITD_2025': 111769.27000000002,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'The Chosen One',
#     'ITD_2023': 1650.0,
#     'ITD_2024': 1733.99,
#     'ITD_2025': 111769.27000000002,
#     '2024_spend': 83.99,
#     '2025_spend': 110035.28000000001,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 111769.27000000002,
#     'Changes': '',
#     'Summary': '$3K consultant fee'}}},
#  {'_id': 'Identical_TV',
#   'title': 'Identical',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 55000.0,
#   'ITD_2025': 35000.0,
#   'Remaining_Committed': 20000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Identical',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 35000.0,
#     '2024_spend': 0.0,
#     '2025_spend': 35000.0,
#     'Remaining_Committed': 20000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 55000.0,
#     'Changes': '',
#     'Summary': 'format fee $20K'}}},
#  {'_id': 'Seized_TV',
#   'title': 'Seized',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 50000.0,
#   'ITD_2025': 50000.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Seized',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 50000.0,
#     '2024_spend': 0.0,
#     '2025_spend': 50000.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 50000.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Made in Utah_TV',
#   'title': 'Made in Utah',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 40467.5,
#   'ITD_2025': 30467.5,
#   'Remaining_Committed': 10000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Made in Utah',
#     'ITD_2023': 30044.25,
#     'ITD_2024': 30044.25,
#     'ITD_2025': 30467.5,
#     '2024_spend': 0.0,
#     '2025_spend': 423.25,
#     'Remaining_Committed': 10000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 40467.5,
#     'Changes': '',
#     'Summary': 'option fee $10K'}}},
#  {'_id': 'Untitled Mallory Project_TV',
#   'title': 'Untitled Mallory Project',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 32478.22999999998,
#   'ITD_2025': 306984.33,
#   'Remaining_Committed': -274506.10000000003,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Untitled Mallory Project',
#     'ITD_2023': 524012.21,
#     'ITD_2024': 274506.10000000003,
#     'ITD_2025': 306984.33,
#     '2024_spend': -249506.11,
#     '2025_spend': 32478.23,
#     'Remaining_Committed': -274506.10000000003,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 32478.22999999998,
#     'Changes': '',
#     'Summary': 'pending reimbursement'}}},
#  {'_id': 'Strangers_TV',
#   'title': 'Strangers',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 30000.0,
#   'ITD_2025': 30000.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Strangers',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 30000.0,
#     '2024_spend': nan,
#     '2025_spend': 30000.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 30000.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Darkside of the Moon_TV',
#   'title': 'Darkside of the Moon',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 29883.33,
#   'ITD_2025': 21333.33,
#   'Remaining_Committed': 8550.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Darkside of the Moon',
#     'ITD_2023': 10000.0,
#     'ITD_2024': 20000.0,
#     'ITD_2025': 21333.33,
#     '2024_spend': 10000.0,
#     '2025_spend': 1333.33,
#     'Remaining_Committed': 8550.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 29883.33,
#     'Changes': '',
#     'Summary': 'dev materials completion'}}},
#  {'_id': 'Unt. Death Hoax_TV',
#   'title': 'Unt. Death Hoax',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 1141.21,
#   'ITD_2025': 1141.21,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Unt. Death Hoax',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 1141.21,
#     '2024_spend': 0.0,
#     '2025_spend': 1141.21,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 1141.21,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Alan Wake_TV',
#   'title': 'Alan Wake',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Alan Wake',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Unt. Shi Yang_TV',
#   'title': 'Unt. Shi Yang',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Unt. Shi Yang',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Unt. Equestrian Series_TV',
#   'title': 'Unt. Equestrian Series',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Unt. Equestrian Series',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Syd_TV',
#   'title': 'Syd',
#   'division': 'tv',
#   'Status': 'inactive',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': -288733.88,
#   'ITD_2025': -288733.88,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'inactive',
#     'title': 'Syd',
#     'ITD_2023': 42902.8,
#     'ITD_2024': 51621.25,
#     'ITD_2025': -288733.88,
#     '2024_spend': 8718.45,
#     '2025_spend': -340355.13,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': -288733.88,
#     'Changes': '',
#     'Summary': 'possible liability to Amazon $340K if principal photography commences'}}},
#  {'_id': 'Heartstring_TV',
#   'title': 'Heartstring',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 90709.29,
#   'ITD_2025': 3584.29,
#   'Remaining_Committed': 87125.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Heartstring',
#     'ITD_2023': 0.0,
#     'ITD_2024': 3584.29,
#     'ITD_2025': 3584.29,
#     '2024_spend': 3584.29,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 87125.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 90709.29,
#     'Changes': '',
#     'Summary': 'option $25K; script fee $50K'}}},
#  {'_id': 'Nomad Summer_TV',
#   'title': 'Nomad Summer',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 70001.2475,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 70001.2475,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Nomad Summer',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 70001.2475,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 70001.2475,
#     'Changes': '',
#     'Summary': 'script option $45K ; rewrite/polish and format fee $25K  + fringe'}}},
#  {'_id': 'Unt. Sports Fan Show_TV',
#   'title': 'Unt. Sports Fan Show',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 30000.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 30000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Unt. Sports Fan Show',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 30000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 30000.0,
#     'Changes': '',
#     'Summary': 'format fee $25K; life rights $5K '}}},
#  {'_id': 'Biggest Little Farm_TV',
#   'title': 'Biggest Little Farm',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 20000.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 20000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Biggest Little Farm',
#     'ITD_2023': nan,
#     'ITD_2024': nan,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': nan,
#     'Remaining_Committed': 20000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 20000.0,
#     'Changes': '',
#     'Summary': 'options $20K'}}},
#  {'_id': 'Unt. Game Doc Series_TV',
#   'title': 'Unt. Game Doc Series',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 4208.32,
#   'ITD_2025': 4208.32,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Unt. Game Doc Series',
#     'ITD_2023': 0.0,
#     'ITD_2024': 1625.0,
#     'ITD_2025': 4208.32,
#     '2024_spend': 1625.0,
#     '2025_spend': 2583.3199999999997,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 4208.32,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Executive Protection_TV',
#   'title': 'Executive Protection',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': nan,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Executive Protection',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': 0.0,
#     'Remaining_Committed': nan,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Unt. John Cho Jean Kyoung Frazier (if/come)_TV',
#   'title': 'Unt. John Cho Jean Kyoung Frazier (if/come)',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': nan,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Unt. John Cho Jean Kyoung Frazier (if/come)',
#     'ITD_2023': nan,
#     'ITD_2024': nan,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': nan,
#     'Remaining_Committed': nan,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Limbo (TV/FILM tbd)_TV',
#   'title': 'Limbo (TV/FILM tbd)',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': nan,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Limbo (TV/FILM tbd)',
#     'ITD_2023': nan,
#     'ITD_2024': nan,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': nan,
#     'Remaining_Committed': nan,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Inside_TV',
#   'title': 'Inside',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': nan,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Inside',
#     'ITD_2023': nan,
#     'ITD_2024': nan,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': nan,
#     'Remaining_Committed': nan,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Exit Party_TV',
#   'title': 'Exit Party',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': nan,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Exit Party',
#     'ITD_2023': nan,
#     'ITD_2024': nan,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': nan,
#     'Remaining_Committed': nan,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': 'book option $100K'}}},
#  {'_id': 'Shot to Nothing_TV',
#   'title': 'Shot to Nothing',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 621250.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 621250.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Shot to Nothing',
#     'ITD_2023': nan,
#     'ITD_2024': nan,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': nan,
#     'Remaining_Committed': 621250.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 621250.0,
#     'Changes': '',
#     'Summary': 'script fee $500K plus fringe'}}},
#  {'_id': 'Murderland_TV',
#   'title': 'Murderland',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 475000.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 475000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Murderland',
#     'ITD_2023': nan,
#     'ITD_2024': nan,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': nan,
#     'Remaining_Committed': 475000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 475000.0,
#     'Changes': '',
#     'Summary': 'option fee $75K and script fee $400K'}}},
#  {'_id': 'Cutter & Tats_TV',
#   'title': 'Cutter & Tats',
#   'division': 'tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': nan,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Cutter & Tats',
#     'ITD_2023': nan,
# ...
#     'Changes': '',
#     'Summary': 'Screenplay option $30K; Graham Annabelle Allocation $37.5K; Misc $10K'}}},
#  {'_id': 'Hellraiser_Animation_Film',
#   'title': 'Hellraiser',
#   'division': 'animation_film',
#   'Status': '',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': '',
#     'title': 'Hellraiser',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Nimona_Animation_Film',
#   'title': 'Nimona',
#   'division': 'animation_film',
#   'Status': '',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 5802.780000000006,
#   'ITD_2025': 5802.780000000006,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': '',
#     'title': 'Nimona',
#     'ITD_2023': 510.3500000000058,
#     'ITD_2024': 5802.780000000006,
#     'ITD_2025': 5802.780000000006,
#     '2024_spend': 5292.43,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 5802.780000000006,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'FOO (Animation)_Animation_Film',
#   'title': 'FOO (Animation)',
#   'division': 'animation_film',
#   'Status': '',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 120167.07000000018,
#   'ITD_2025': 120167.07000000018,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': '',
#     'title': 'FOO (Animation)',
#     'ITD_2023': 899456.3900000001,
#     'ITD_2024': 910403.3700000002,
#     'ITD_2025': 120167.07000000018,
#     '2024_spend': 10946.980000000056,
#     '2025_spend': -790236.3,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 120167.07000000018,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': "Let's Boogey_Animation_Film",
#   'title': "Let's Boogey",
#   'division': 'animation_film',
#   'Status': '',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 1568.98,
#   'ITD_2025': 1568.98,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': '',
#     'title': "Let's Boogey",
#     'ITD_2023': 1568.98,
#     'ITD_2024': 1568.98,
#     'ITD_2025': 1568.98,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 1568.98,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Some Assembly Required_Animation_Film',
#   'title': 'Some Assembly Required',
#   'division': 'animation_film',
#   'Status': '',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 714649.81,
#   'ITD_2025': 281652.20999999996,
#   'Remaining_Committed': 215743.8,
#   'Remaining_Optional': nan,
#   'Changes': 'added Nick and Paul for 2026 @ 20%',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': '',
#     'title': 'Some Assembly Required',
#     'ITD_2023': 0.0,
#     'ITD_2024': 1695.4900000000018,
#     'ITD_2025': 281652.20999999996,
#     '2024_spend': 1695.4900000000018,
#     '2025_spend': 279956.72,
#     'Remaining_Committed': 215743.8,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 714649.81,
#     'Changes': 'added Nick and Paul for 2026 @ 20%',
#     'Summary': ''}}},
#  {'_id': 'The Trap_Animation_Film',
#   'title': 'The Trap',
#   'division': 'animation_film',
#   'Status': '',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 7921.62,
#   'ITD_2025': 7921.62,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': '',
#     'title': 'The Trap',
#     'ITD_2023': 0.0,
#     'ITD_2024': 615.0,
#     'ITD_2025': 7921.62,
#     '2024_spend': 615.0,
#     '2025_spend': 7306.62,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 7921.62,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Nick Weidenfeld_Animation_TV',
#   'title': 'Nick Weidenfeld',
#   'division': 'animation_tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 771196.0,
#   'ITD_2025': 478804.32,
#   'Remaining_Committed': 146195.68,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Nick Weidenfeld',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 478804.32,
#     '2024_spend': 0.0,
#     '2025_spend': 478804.32,
#     'Remaining_Committed': 146195.68,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 771196.0,
#     'Changes': '',
#     'Summary': 'Weidenfeld $550K + assistant $75K'}}},
#  {'_id': 'Sapiens - Animation_Animation_TV',
#   'title': 'Sapiens - Animation',
#   'division': 'animation_tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 81875.04000000001,
#   'ITD_2025': 81875.04000000001,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Sapiens - Animation',
#     'ITD_2023': 6860.27,
#     'ITD_2024': 6875.040000000001,
#     'ITD_2025': 81875.04000000001,
#     '2024_spend': 14.77,
#     '2025_spend': 75000.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 81875.04000000001,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Witchfeld_Animation_TV',
#   'title': 'Witchfeld',
#   'division': 'animation_tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Witchfeld',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Living the Dream_Animation_TV',
#   'title': 'Living the Dream',
#   'division': 'animation_tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Living the Dream',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'NARPS (Non-Associated Regular People)_Animation_TV',
#   'title': 'NARPS (Non-Associated Regular People)',
#   'division': 'animation_tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'NARPS (Non-Associated Regular People)',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Outlets_Animation_TV',
#   'title': 'Outlets',
#   'division': 'animation_tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Outlets',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': '20,000 Leagues Under the Sea_Animation_TV',
#   'title': '20,000 Leagues Under the Sea',
#   'division': 'animation_tv',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': '20,000 Leagues Under the Sea',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': 0.0,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Donut County - Anim/TV_Animation_TV',
#   'title': 'Donut County - Anim/TV',
#   'division': 'animation_tv',
#   'Status': 'inactive',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 332672.55,
#   'ITD_2025': 332672.55,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'inactive',
#     'title': 'Donut County - Anim/TV',
#     'ITD_2023': 0.0,
#     'ITD_2024': 321417.86,
#     'ITD_2025': 332672.55,
#     '2024_spend': 321417.86,
#     '2025_spend': 11254.69,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 332672.55,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Center Stage_Theatre',
#   'title': 'Center Stage',
#   'division': 'theatre',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 340000.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 170000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Center Stage',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 170000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 340000.0,
#     'Changes': '',
#     'Summary': 'option fee $70K; $100K dev fee'}}},
#  {'_id': 'Her_Theatre',
#   'title': 'Her',
#   'division': 'theatre',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 100000.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': 50000.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Her',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': 0.0,
#     'Remaining_Committed': 50000.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 100000.0,
#     'Changes': '',
#     'Summary': 'dev fee $50K'}}},
#  {'_id': 'Inter Alia (Broadway 2026)_Theatre',
#   'title': 'Inter Alia (Broadway 2026)',
#   'division': 'theatre',
#   'Status': 'pending',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 0.0,
#   'ITD_2025': 0.0,
#   'Remaining_Committed': nan,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'pending',
#     'title': 'Inter Alia (Broadway 2026)',
#     'ITD_2023': nan,
#     'ITD_2024': 0.0,
#     'ITD_2025': 0.0,
#     '2024_spend': nan,
#     '2025_spend': nan,
#     'Remaining_Committed': nan,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 0.0,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Case of the Existence of God_Theatre',
#   'title': 'Case of the Existence of God',
#   'division': 'theatre',
#   'Status': 'inactive',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 8593.17,
#   'ITD_2025': 8593.17,
#   'Remaining_Committed': 0.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'inactive',
#     'title': 'Case of the Existence of God',
#     'ITD_2023': 0.0,
#     'ITD_2024': 0.0,
#     'ITD_2025': 8593.17,
#     '2024_spend': 0.0,
#     '2025_spend': 8593.17,
#     'Remaining_Committed': 0.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 8593.17,
#     'Changes': '',
#     'Summary': ''}}},
#  {'_id': 'Stephen Feder fee_Film',
#   'title': 'Stephen Feder fee',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 639379.56,
#   'ITD_2025': 568217.56,
#   'Remaining_Committed': 71162.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Stephen Feder fee',
#     'ITD_2023': 0.0,
#     'ITD_2024': 176824.8,
#     'ITD_2025': 568217.56,
#     '2024_spend': 176824.8,
#     '2025_spend': 391392.7600000001,
#     'Remaining_Committed': 71162.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 639379.56,
#     'Changes': '',
#     'Summary': '5 months of fee $178K'}}},
#  {'_id': 'Conner (Literary Research)_Film',
#   'title': 'Conner (Literary Research)',
#   'division': 'film',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 257850.0,
#   'ITD_2025': 220150.0,
#   'Remaining_Committed': 37700.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Conner (Literary Research)',
#     'ITD_2023': 153450.0,
#     'ITD_2024': 188250.0,
#     'ITD_2025': 220150.0,
#     '2024_spend': 34800.0,
#     '2025_spend': 31900.0,
#     'Remaining_Committed': 37700.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 257850.0,
#     'Changes': '',
#     'Summary': '15 months @ $2.9K/mo'}}},
#  {'_id': 'Conner (Literary Research)_TV',
#   'title': 'Conner (Literary Research)',
#   'division': 'tv',
#   'Status': 'closed deals/active',
#   'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#   'Total_Cost_with_Committments': 257850.0,
#   'ITD_2025': 220150.0,
#   'Remaining_Committed': 37700.0,
#   'Remaining_Optional': nan,
#   'Changes': '',
#   '$push': {'updates': {'update_date': Timestamp('2025-12-10 06:09:21.519864'),
#     'Status': 'closed deals/active',
#     'title': 'Conner (Literary Research)',
#     'ITD_2023': 153450.0,
#     'ITD_2024': 188250.0,
#     'ITD_2025': 220150.0,
#     '2024_spend': 34800.0,
#     '2025_spend': 31900.0,
#     'Remaining_Committed': 37700.0,
#     'Remaining_Optional': nan,
#     'Total_Cost_with_Committments': 257850.0,
#     'Changes': '',
#     'Summary': '15 months @ $2.9K/mo'}}}]

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %% [raw]
# collection.delete_many({})

# %%
from pymongo import UpdateOne

operations = []

for doc in doc_list:
    # Split update payloads
    base_fields = {
        'title': doc['title'],
        'division': doc['division'],
        'status':doc['Status'],
        'update_date': doc['update_date'],
        'Total_Cost_with_Committments': doc['Total_Cost_with_Committments'],
        'ITD_2025': doc['ITD_2025'],
        'Remaining_Committed': doc['Remaining_Committed'],
        'Remaining_Optional': doc['Remaining_Optional'],
    }

    new_update = doc['$push']['updates']  # from your earlier construction

    operations.append(
        UpdateOne(
            {"_id": doc["_id"]},
            {
                "$set": base_fields,
                "$push": {"updates": new_update}
            },
            upsert=True
        )
    )

result = collection.bulk_write(operations)
print(f"Matched: {result.matched_count}, Upserted: {len(result.upserted_ids)}, Modified: {result.modified_count}")
# Out:
# Matched: 97, Upserted: 1, Modified: 97

# %%
docs = collection.find({})

# %%
df = pd.DataFrame(docs)

# %%
df.sort_values(by='Total_Cost_with_Committments',ascending=False)
# Out:
#                                          _id    ITD_2025  Remaining_Committed  \
# 0    Even the Losers/ Unt. Randy Lanier_Film  2089738.50            3013125.0
# 18                   Eric Warren Singer_Film        0.00            4500000.0
# 78                   Mantooth_Animation_Film  2296780.64             120000.0
# 1           The Silent Patient - Plan B_Film  1940770.55              31062.5
# 82                    Moomins_Animation_Film   527887.81             285250.0
# ..                                       ...         ...                  ...
# 60                 Unt. Equestrian Series_TV        0.00                  0.0
# 76                        Kill the Rabbit_TV        0.00                  NaN
# 70                             Exit Party_TV        0.00                  NaN
# 41                                    Syd_TV  -288733.88                  0.0
# 105                     Gravity Let Me Go_TV        0.00              65400.0
#
#      Remaining_Optional  Total_Cost_with_Committments        division  \
# 0              750000.0                    5852863.50            film
# 18                  NaN                    4500000.00            film
# 78                  NaN                    2416780.64  animation_film
# 1               62125.0                    2033958.05            film
# 82                  NaN                    1056887.81  animation_film
# ..                  ...                           ...             ...
# 60                  NaN                          0.00              tv
# 76                  NaN                          0.00              tv
# 70                  NaN                          0.00              tv
# 41                  NaN                    -288733.88              tv
# 105                 NaN                           NaN              tv
#
#                   status                               title  \
# 0    closed deals/active  Even the Losers/ Unt. Randy Lanier
# 18               pending                  Eric Warren Singer
# 78                                                  Mantooth
# 1    closed deals/active         The Silent Patient - Plan B
# 82                                                   Moomins
# ..                   ...                                 ...
# 60   closed deals/active              Unt. Equestrian Series
# 76               pending                     Kill the Rabbit
# 70               pending                          Exit Party
# 41              inactive                                 Syd
# 105              pending                   Gravity Let Me Go
#
#                 update_date  \
# 0   2025-12-10 06:09:21.519
# 18  2025-12-10 06:09:21.519
# 78  2025-12-10 06:09:21.519
# 1   2025-12-10 06:09:21.519
# 82  2025-12-10 06:09:21.519
# ..                      ...
# 60  2025-12-10 06:09:21.519
# 76  2025-12-10 06:09:21.519
# 70  2025-12-10 06:09:21.519
# 41  2025-12-10 06:09:21.519
# 105 2025-12-10 06:09:21.519
#
#                                                updates          ap_id
# 0    [{'update_date': 2025-10-31 10:35:01.546000, '...   F_2025_00018
# 18   [{'update_date': 2025-10-31 10:35:01.546000, '...            NaN
# 78   [{'update_date': 2025-10-31 10:35:01.546000, '...  AN_2025_00014
# 1    [{'update_date': 2025-10-31 10:35:01.546000, '...   F_2025_00048
# 82   [{'update_date': 2025-10-31 10:35:01.546000, '...  AN_2025_00005
# ..                                                 ...            ...
# 60   [{'update_date': 2025-10-31 10:35:01.546000, '...  TV_2025_00018
# 76   [{'update_date': 2025-10-31 10:35:01.546000, '...            NaN
# 70   [{'update_date': 2025-10-31 10:35:01.546000, '...            NaN
# 41   [{'update_date': 2025-10-31 10:35:01.546000, '...            NaN
# 105  [{'update_date': 2025-12-10 06:09:21.519000, '...            NaN
#
# [106 rows x 11 columns]

# %%
client.close()

# %%
df.groupby('division')['Total_Cost_with_Committments'].sum()/1_000_000
# Out:
# division
# animation_film     6.137974
# animation_tv       1.185744
# corporate          1.053055
# film              20.379808
# theatre            0.448593
# tv                 6.277826
# Name: Total_Cost_with_Committments, dtype: float64

# %%
df.query("division =='corporate'")
# Out:
#                                   _id   ITD_2025  Remaining_Committed  \
# 77   England Expects (Film)_corporate   46154.00                  NaN
# 79           Counterculture_corporate  921893.26                  NaN
# 80                 Calliope_corporate   41107.97              33900.0
# 103         Grant & Sherman_corporate   10000.00                  0.0
#
#      Remaining_Optional  Total_Cost_with_Committments   division  \
# 77                  NaN                      46154.00  corporate
# 79                  NaN                     921893.26  corporate
# 80                  NaN                      75007.97  corporate
# 103                 NaN                      10000.00  corporate
#
#                   status                   title             update_date  \
# 77               pending  England Expects (Film) 2025-12-10 06:09:21.519
# 79   closed deals/active          Counterculture 2025-11-10 05:40:42.156
# 80   closed deals/active                Calliope 2025-12-10 06:09:21.519
# 103  closed deals/active         Grant & Sherman 2025-12-10 06:09:21.519
#
#                                                updates ap_id
# 77   [{'update_date': 2025-10-31 10:35:01.546000, '...   NaN
# 79   [{'update_date': 2025-10-31 10:35:01.546000, '...   NaN
# 80   [{'update_date': 2025-10-31 10:35:01.546000, '...   NaN
# 103  [{'update_date': 2025-11-10 05:34:58.644000, '...   NaN
